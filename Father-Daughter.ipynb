# %%
import pandas as pd

file_path = '/Users/rolanddelarosa/Desktop/THESIS VERSION 2/Cleaned Files 1/AgeFiltered_CleanedData.csv'

# Read just the header to get the column names
header = pd.read_csv(file_path, nrows=0)
col_names = header.columns

# Now use the column names at index 17 and 18
dtype_dict = {col_names[17]: str, col_names[18]: str}

# Now read the CSV with the dtype_dict applied
df = pd.read_csv(file_path, dtype=dtype_dict)

df.head()
# Out:
#    OrigHHNUM  Year  Quarter Household_Number  Region  Urban_Rural  \
# 0          4  2016        2           2/2/16       1            2
# 1          4  2016        2           2/2/16       1            2
# 2          5  2016        2           2/3/16       1            2
# 3          5  2016        2           2/3/16       1            2
# 4         10  2016        2           2/5/16       1            2
#
#    Children_Per_Household  Parent_Sex  Child_Sex  Parent_Age  ...  \
# 0                       2           1          1          51  ...
# 1                       2           2          1          51  ...
# 2                       1           1          1          71  ...
# 3                       1           2          1          54  ...
# 4                       1           1          1          72  ...
#
#    Child_Marital_Status  Parent_Educational_Attainment  \
# 0                     1                              5
# 1                     1                              9
# 2                     1                              2
# 3                     1                              2
# 4                     4                              3
#
#    Child_Educational_Attainment  Parent_Schooling_Years  \
# 0                             9                      10
# 1                             9                      14
# 2                             9                       4
# 3                             9                       2
# 4                             5                       6
#
#    Child_Schooling_Years  Parent_Primary_Occupation  Child_Primary_Occupation  \
# 0                     14                          1                       NaN
# 1                     14                        NaN                       NaN
# 2                     14                          9                         1
# 3                     14                          9                         1
# 4                     10                          6                         1
#
#   Parent_WagePerDay Child_WagePerDay Child_Birth_Cohort
# 0                                                  1990
# 1                                                  1990
# 2               350              909               1989
# 3               200              909               1989
# 4                                                  1977
#
# [5 rows x 22 columns]

# %% [markdown]
# <span style="font-family:monospace; font-size:15px;"><b>Age Cleaning and Adding Log Incomes</b></span>
#
#
# - Child Age (25-45)
# - Parent Age (45-64)
# - Natural Logarithmic of the Incomes
# - Adding the Birth_Cohort Groups
# - Filtering missing data of income (both parent & child)

# %%
import pandas as pd
import numpy as np

# Ensure numeric types
df['Parent_Age'] = pd.to_numeric(df['Parent_Age'], errors='coerce')
df['Child_Age'] = pd.to_numeric(df['Child_Age'], errors='coerce')
df['Parent_WagePerDay'] = pd.to_numeric(df['Parent_WagePerDay'], errors='coerce')
df['Child_WagePerDay'] = pd.to_numeric(df['Child_WagePerDay'], errors='coerce')

# Filter by age
filtered_df = df[(df['Parent_Age'] >= 45) & (df['Parent_Age'] <= 64) &
                 (df['Child_Age'] >= 25) & (df['Child_Age'] <= 45)].copy()

# Apply log (avoid log(0))
filtered_df['Parent_LogIncome'] = np.log(filtered_df['Parent_WagePerDay'].replace(0, np.nan))
filtered_df['Child_LogIncome'] = np.log(filtered_df['Child_WagePerDay'].replace(0, np.nan))

# Remove rows where either Parent or Child log income is missing
filtered_df = filtered_df.dropna(subset=['Parent_LogIncome', 'Child_LogIncome'])

# Define bins and labels for 5-year cohorts from 1970-1974 to 2000-2004
bins = [1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005]
labels = [
    '1970-1974',
    '1975-1979',
    '1980-1984',
    '1985-1989',
    '1990-1994',
    '1995-1999',
    '2000-2004'
]

# Assign cohorts to the filtered_df
filtered_df['Birth_Cohort'] = pd.cut(
    filtered_df['Child_Birth_Cohort'],
    bins=bins,
    labels=labels,
    right=False,          # left-inclusive: 1970 <= x < 1975 => '1970-1974'
    include_lowest=True
)

# Create descriptive frequency table for the filtered data
freq_table = filtered_df['Birth_Cohort'].value_counts(dropna=False).sort_index()
percent_table = filtered_df['Birth_Cohort'].value_counts(normalize=True, dropna=False).sort_index() * 100

descriptive_freq = pd.DataFrame({
    'Frequency': freq_table,
    'Percentage': percent_table.round(2)
})

print(descriptive_freq)
filtered_df.head()
# Out:
#               Frequency  Percentage
# Birth_Cohort
# 1970-1974            48        0.06
# 1975-1979           722        0.96
# 1980-1984          4161        5.51
# 1985-1989         15136       20.05
# 1990-1994         34187       45.28
# 1995-1999         21246       28.14
# 2000-2004             0        0.00
#     OrigHHNUM  Year  Quarter Household_Number  Region  Urban_Rural  \
# 3           5  2016        2           2/3/16       1            2
# 17         45  2016        2          2/14/16       1            2
# 18         45  2016        2          2/14/16       1            2
# 27         59  2016        2          2/19/16       1            2
# 35         63  2016        2          2/21/16       1            2
#
#     Children_Per_Household  Parent_Sex  Child_Sex  Parent_Age  ...  \
# 3                        1           2          1          54  ...
# 17                       2           1          1          54  ...
# 18                       2           2          1          54  ...
# 27                       2           2          2          46  ...
# 35                       2           2          1          58  ...
#
#     Parent_Schooling_Years  Child_Schooling_Years  Parent_Primary_Occupation  \
# 3                        2                     14                          9
# 17                       3                      6                          9
# 18                       6                      6                          9
# 27                      10                     12                          9
# 35                      12                     14                          5
#
#     Child_Primary_Occupation  Parent_WagePerDay  Child_WagePerDay  \
# 3                          1              200.0             909.0
# 17                         9              200.0             200.0
# 18                         9              200.0             200.0
# 27                         5              200.0             300.0
# 35                         5              454.0             423.0
#
#     Child_Birth_Cohort Parent_LogIncome Child_LogIncome  Birth_Cohort
# 3                 1989         5.298317        6.812345     1985-1989
# 17                1988         5.298317        5.298317     1985-1989
# 18                1988         5.298317        5.298317     1985-1989
# 27                1988         5.298317        5.703782     1985-1989
# 35                1982         6.118097        6.047372     1980-1984
#
# [5 rows x 25 columns]

# %%
import pandas as pd
import numpy as np

# --- Region and sex code mapping ---
region_map = {
    13: 'NCR', 14: 'CAR', 1: 'Region I', 2: 'Region II', 3: 'Region III', 4: 'Region IV-A',
    17: 'MIMAROPA', 5: 'Region V', 6: 'Region VI', 7: 'Region VII', 8: 'Region VIII',
    9: 'Region IX', 10: 'Region X', 11: 'Region XI', 12: 'Region XII', 16: 'Region XIII', 15: 'ARMM'
}
parent_sex_map = {1: 'Father', 2: 'Mother'}
child_sex_map = {1: 'Son', 2: 'Daughter'}

# --- Data cleaning: remove rows with missing parent/child income ---
# Assumes you have already created Parent_LogIncome and Child_LogIncome columns
complete_df = filtered_df.dropna(subset=['Parent_LogIncome', 'Child_LogIncome']).copy()

# Apply mappings
complete_df['Region'] = complete_df['Region'].map(region_map)
complete_df['Parent_Sex'] = complete_df['Parent_Sex'].map(parent_sex_map)
complete_df['Child_Sex'] = complete_df['Child_Sex'].map(child_sex_map)

# --- Count per group ---
sample_counts = (
    complete_df
    .groupby(['Region', 'Parent_Sex', 'Child_Sex'])
    .size()
    .reset_index(name='Samples_in_Investigation')
    .sort_values(['Region', 'Parent_Sex', 'Child_Sex'])
)

# --- Pivot to matrix style table ---
pivot_table = (
    sample_counts
    .pivot(index='Region', columns=['Parent_Sex', 'Child_Sex'], values='Samples_in_Investigation')
    .fillna(0).astype(int)
)

# --- Total per region (all pairs) ---
region_totals = (
    complete_df.groupby('Region').size().rename('Total_Region').to_frame()
)

# --- Total per sex pair (all regions) ---
pair_totals = (
    complete_df.groupby(['Parent_Sex', 'Child_Sex']).size().rename('Total_Pair').to_frame()
)

# --- Display tables ---
print("\nSAMPLES PER REGION AND PARENT/CHILD SEX PAIR:")
print(pivot_table)

print("\nTOTAL COMPLETE SAMPLES PER REGION (all pairs):")
print(region_totals)

print("\nTOTAL COMPLETE SAMPLES PER SEX PAIR (all regions):")
print(pair_totals)
# Out:
# SAMPLES PER REGION AND PARENT/CHILD SEX PAIR:
# Parent_Sex    Father         Mother
# Child_Sex   Daughter   Son Daughter   Son
# Region
# ARMM             129   280      140   190
# CAR              727  1341      870  1311
# MIMAROPA         496   907      519   728
# NCR             4405  5977     2866  3921
# Region I         526  1222      501  1157
# Region II        559  1131      638  1252
# Region III      1556  2761     1023  1831
# Region IV-A     1099  1643      765  1168
# Region IX        388   687      328   480
# Region V         570  1083      543   808
# Region VI       1062  1726      975  1544
# Region VII      1254  1765      906  1271
# Region VIII      751  1277      705  1035
# Region X         897  1551      704  1148
# Region XI        557  1327      447   832
# Region XII       403   802      374   731
# Region XIII      524  1070      495   841
#
# TOTAL COMPLETE SAMPLES PER REGION (all pairs):
#              Total_Region
# Region
# ARMM                  739
# CAR                  4249
# MIMAROPA             2650
# NCR                 17169
# Region I             3406
# Region II            3580
# Region III           7171
# Region IV-A          4675
# Region IX            1883
# Region V             3004
# Region VI            5307
# Region VII           5196
# Region VIII          3768
# Region X             4300
# Region XI            3163
# Region XII           2310
# Region XIII          2930
#
# TOTAL COMPLETE SAMPLES PER SEX PAIR (all regions):
#                       Total_Pair
# Parent_Sex Child_Sex
# Father     Daughter        15903
#            Son             26550
# Mother     Daughter        12799
#            Son             20248

# %%
import pandas as pd

# Use your complete_df as the dataset
complete_df = complete_df.copy()

# Filter for father-daughter pairs (Parent_Sex == 'Father', Child_Sex == 'Daughter')
complete_df = complete_df[(complete_df['Parent_Sex'] == 'Father') & (complete_df['Child_Sex'] == 'Daughter')]

# Ensure Region is categorical
complete_df['Region'] = complete_df['Region'].astype('category')

# Centralize child age to 30
complete_df['Central_Child_Age'] = complete_df['Child_Age'] - 30

# Squared centralized child age
complete_df['Central_Child_Age2'] = complete_df['Central_Child_Age'] ** 2

# Centralize parent log income by its mean
mean_parent_log_income = complete_df['Parent_LogIncome'].mean()
complete_df['Central_Parent_LogIncome'] = complete_df['Parent_LogIncome'] - mean_parent_log_income

# Child_Age_CLogIncome: Central_Child_Age * Centralized Parent_LogIncome
complete_df['Child_Age_CLogIncome'] = complete_df['Central_Child_Age'] * complete_df['Central_Parent_LogIncome']

# Child_Age^2_CLogIncome: Central_Child_Age^2 * Centralized Parent_LogIncome
complete_df['Child_Age2_CLogIncome'] = complete_df['Central_Child_Age2'] * complete_df['Central_Parent_LogIncome']

# Centralize parent age to 50
complete_df['Central_Parent_Age'] = complete_df['Parent_Age'] - 50

# Squared centralized parent age
complete_df['Central_Parent_Age2'] = complete_df['Central_Parent_Age'] ** 2

complete_df.head()
# Out:
#      OrigHHNUM  Year  Quarter Household_Number    Region  Urban_Rural  \
# 54         118  2016        2       2016-02-40  Region I            2
# 55         118  2016        2       2016-02-40  Region I            2
# 181        368  2016        2      2016-02-127  Region I            2
# 226        450  2016        2      2016-02-159  Region I            2
# 348        619  2016        2      2016-02-221  Region I            2
#
#      Children_Per_Household Parent_Sex Child_Sex  Parent_Age  ...  \
# 54                        2     Father  Daughter          55  ...
# 55                        2     Father  Daughter          55  ...
# 181                       3     Father  Daughter          48  ...
# 226                       3     Father  Daughter          55  ...
# 348                       4     Father  Daughter          64  ...
#
#      Parent_LogIncome  Child_LogIncome  Birth_Cohort  Central_Child_Age  \
# 54           7.282761         6.812345     1985-1989                 -3
# 55           7.282761         6.188264     1990-1994                 -4
# 181          5.609472         5.010635     1990-1994                 -5
# 226          5.857933         5.703782     1985-1989                 -2
# 348          6.455199         5.545177     1985-1989                 -2
#
#      Central_Child_Age2  Central_Parent_LogIncome  Child_Age_CLogIncome  \
# 54                    9                  1.051715             -3.155146
# 55                   16                  1.051715             -4.206862
# 181                  25                 -0.621574              3.107870
# 226                   4                 -0.373113              0.746225
# 348                   4                  0.224153             -0.448306
#
#     Child_Age2_CLogIncome Central_Parent_Age  Central_Parent_Age2
# 54               9.465439                  5                   25
# 55              16.827447                  5                   25
# 181            -15.539349                 -2                    4
# 226             -1.492450                  5                   25
# 348              0.896611                 14                  196
#
# [5 rows x 32 columns]

# %% [markdown]
# <span style="font-family:monospace; font-size:18px;"><b>Income Bayesian Multilevel/Hierarchical Modelling</b></span>

# %%
# If not installed, uncomment and run:
# %pip install bambi pymc arviz

import pandas as pd
import bambi as bmb
import arviz as az

# %%
#Setting the Dataframe
df = complete_df.copy()

# Specify the prior for Parent_LogIncome
priors = {
    "Parent_LogIncome": bmb.Prior("Normal", mu=0.4, sigma=0.10)
}

# Update the formula to include new controls
formula = (
    "Child_LogIncome ~ Parent_LogIncome + Children_Per_Household + C(Year) "
    "+ Central_Child_Age + Central_Child_Age2 "
    "+ Child_Age_CLogIncome + Child_Age2_CLogIncome "
    "+ Central_Parent_Age + Central_Parent_Age2 "
    "+ (1 + Parent_LogIncome | Region)"
)

model = bmb.Model(formula, df, family="gaussian", priors=priors)

results1 = model.fit(
    draws=2000, tune=2000, random_seed=42, cores=1, chains=4, target_accept=0.995
)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, Parent_LogIncome, Children_Per_Household, C(Year), Central_Child_Age, Central_Child_Age2, Child_Age_CLogIncome, Child_Age2_CLogIncome, Central_Parent_Age, Central_Parent_Age2, 1|Region_sigma, 1|Region_offset, Parent_LogIncome|Region_sigma, Parent_LogIncome|Region_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 1726 seconds.

# %%
# Show summary of selected parameters - with Random Slopes
print(az.summary(
    results1,
    var_names=[
        "~sigma", "~Intercept", "Parent_LogIncome", "Children_Per_Household", "C(Year)",
        "Central_Child_Age", "Central_Child_Age2", "Child_Age_CLogIncome", "Child_Age2_CLogIncome",
        "Central_Parent_Age", "Central_Parent_Age2"
    ]
))
# Out:
#                                        mean     sd  hdi_3%  hdi_97%  \
# Parent_LogIncome                      0.393  0.010   0.374    0.412
# Children_Per_Household               -0.027  0.003  -0.032   -0.022
# C(Year)[2017]                        -0.008  0.020  -0.046    0.028
# C(Year)[2018]                         0.064  0.019   0.026    0.099
# C(Year)[2019]                         0.144  0.023   0.102    0.186
# C(Year)[2020]                         0.146  0.020   0.110    0.187
# C(Year)[2021]                         0.192  0.018   0.158    0.225
# C(Year)[2022]                         0.192  0.018   0.160    0.226
# C(Year)[2023]                         0.224  0.018   0.189    0.257
# Central_Child_Age                    -0.003  0.001  -0.005   -0.000
# Central_Child_Age2                   -0.001  0.000  -0.001   -0.000
# Child_Age_CLogIncome                  0.008  0.002   0.004    0.012
# Child_Age2_CLogIncome                -0.001  0.000  -0.002    0.000
# Central_Parent_Age                    0.007  0.002   0.003    0.011
# Central_Parent_Age2                  -0.000  0.000  -0.001    0.000
# 1|Region_sigma                        0.086  0.022   0.051    0.123
# Parent_LogIncome|Region_sigma         0.004  0.003   0.000    0.009
# 1|Region[ARMM]                       -0.056  0.048  -0.148    0.031
# 1|Region[CAR]                         0.043  0.037  -0.025    0.112
# 1|Region[MIMAROPA]                    0.013  0.039  -0.059    0.085
# 1|Region[NCR]                         0.230  0.040   0.161    0.297
# 1|Region[Region I]                   -0.088  0.039  -0.151   -0.010
# 1|Region[Region II]                  -0.009  0.038  -0.079    0.061
# 1|Region[Region III]                  0.037  0.036  -0.028    0.106
# 1|Region[Region IV-A]                 0.079  0.035   0.013    0.145
# 1|Region[Region IX]                  -0.010  0.041  -0.086    0.065
# 1|Region[Region V]                   -0.052  0.039  -0.125    0.017
# 1|Region[Region VI]                  -0.011  0.035  -0.077    0.054
# 1|Region[Region VII]                  0.041  0.037  -0.027    0.108
# 1|Region[Region VIII]                -0.036  0.037  -0.103    0.035
# 1|Region[Region X]                   -0.044  0.036  -0.109    0.022
# 1|Region[Region XI]                  -0.031  0.039  -0.098    0.044
# 1|Region[Region XII]                 -0.065  0.039  -0.135    0.010
# 1|Region[Region XIII]                -0.037  0.038  -0.105    0.037
# Parent_LogIncome|Region[ARMM]        -0.001  0.004  -0.009    0.007
# Parent_LogIncome|Region[CAR]          0.000  0.004  -0.008    0.008
# Parent_LogIncome|Region[MIMAROPA]     0.001  0.004  -0.007    0.009
# Parent_LogIncome|Region[NCR]         -0.001  0.005  -0.011    0.007
# Parent_LogIncome|Region[Region I]     0.000  0.004  -0.008    0.008
# Parent_LogIncome|Region[Region II]    0.001  0.004  -0.007    0.009
# Parent_LogIncome|Region[Region III]  -0.000  0.004  -0.008    0.008
# Parent_LogIncome|Region[Region IV-A]  0.000  0.004  -0.008    0.009
# Parent_LogIncome|Region[Region IX]    0.000  0.004  -0.008    0.009
# Parent_LogIncome|Region[Region V]     0.001  0.004  -0.008    0.009
# Parent_LogIncome|Region[Region VI]    0.000  0.004  -0.007    0.008
# Parent_LogIncome|Region[Region VII]  -0.001  0.004  -0.008    0.008
# Parent_LogIncome|Region[Region VIII]  0.000  0.004  -0.008    0.008
# Parent_LogIncome|Region[Region X]    -0.000  0.004  -0.009    0.008
# Parent_LogIncome|Region[Region XI]    0.000  0.004  -0.008    0.008
# Parent_LogIncome|Region[Region XII]  -0.001  0.004  -0.009    0.007
# Parent_LogIncome|Region[Region XIII] -0.001  0.004  -0.009    0.007
#
#                                       mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# Parent_LogIncome                          0.000    0.000    7288.0    6075.0
# Children_Per_Household                    0.000    0.000   11252.0    6081.0
# C(Year)[2017]                             0.000    0.000    4095.0    5165.0
# C(Year)[2018]                             0.000    0.000    3915.0    5569.0
# C(Year)[2019]                             0.000    0.000    4548.0    5253.0
# C(Year)[2020]                             0.000    0.000    4063.0    5372.0
# C(Year)[2021]                             0.000    0.000    3345.0    4949.0
# C(Year)[2022]                             0.000    0.000    3345.0    5258.0
# C(Year)[2023]                             0.000    0.000    3500.0    5021.0
# Central_Child_Age                         0.000    0.000    9610.0    5932.0
# Central_Child_Age2                        0.000    0.000    9695.0    6048.0
# Child_Age_CLogIncome                      0.000    0.000    8898.0    6144.0
# Child_Age2_CLogIncome                     0.000    0.000    7842.0    6292.0
# Central_Parent_Age                        0.000    0.000    7372.0    6171.0
# Central_Parent_Age2                       0.000    0.000    7783.0    6028.0
# 1|Region_sigma                            0.001    0.001    1484.0    2166.0
# Parent_LogIncome|Region_sigma             0.000    0.000    1203.0    1356.0
# 1|Region[ARMM]                            0.001    0.001    6197.0    5520.0
# 1|Region[CAR]                             0.001    0.001    4022.0    4126.0
# 1|Region[MIMAROPA]                        0.001    0.001    4244.0    4015.0
# 1|Region[NCR]                             0.001    0.002    2266.0    1806.0
# 1|Region[Region I]                        0.001    0.001    4115.0    4473.0
# 1|Region[Region II]                       0.001    0.001    3926.0    4055.0
# 1|Region[Region III]                      0.001    0.001    3337.0    3519.0
# 1|Region[Region IV-A]                     0.001    0.001    3852.0    4472.0
# 1|Region[Region IX]                       0.001    0.001    4778.0    5168.0
# 1|Region[Region V]                        0.001    0.001    4047.0    3808.0
# 1|Region[Region VI]                       0.001    0.001    3890.0    4672.0
# 1|Region[Region VII]                      0.001    0.001    3114.0    3964.0
# 1|Region[Region VIII]                     0.001    0.001    4049.0    4602.0
# 1|Region[Region X]                        0.001    0.001    3968.0    4823.0
# 1|Region[Region XI]                       0.001    0.001    4451.0    5189.0
# 1|Region[Region XII]                      0.001    0.001    4781.0    5546.0
# 1|Region[Region XIII]                     0.001    0.001    4293.0    4005.0
# Parent_LogIncome|Region[ARMM]             0.000    0.000    9725.0    4253.0
# Parent_LogIncome|Region[CAR]              0.000    0.000    8630.0    4634.0
# Parent_LogIncome|Region[MIMAROPA]         0.000    0.000    7574.0    3076.0
# Parent_LogIncome|Region[NCR]              0.000    0.000    3682.0    1874.0
# Parent_LogIncome|Region[Region I]         0.000    0.000    7427.0    3596.0
# Parent_LogIncome|Region[Region II]        0.000    0.000    6295.0    3695.0
# Parent_LogIncome|Region[Region III]       0.000    0.000    7198.0    3830.0
# Parent_LogIncome|Region[Region IV-A]      0.000    0.000    9140.0    4576.0
# Parent_LogIncome|Region[Region IX]        0.000    0.000    8991.0    4021.0
# Parent_LogIncome|Region[Region V]         0.000    0.000    6774.0    3211.0
# Parent_LogIncome|Region[Region VI]        0.000    0.000    8755.0    4120.0
# Parent_LogIncome|Region[Region VII]       0.000    0.000    7244.0    3375.0
# Parent_LogIncome|Region[Region VIII]      0.000    0.000    9231.0    3857.0
# Parent_LogIncome|Region[Region X]         0.000    0.000    8680.0    3452.0
# Parent_LogIncome|Region[Region XI]        0.000    0.000    8465.0    3889.0
# Parent_LogIncome|Region[Region XII]       0.000    0.000    9467.0    3912.0
# Parent_LogIncome|Region[Region XIII]      0.000    0.000    7602.0    3944.0
#
#                                       r_hat
# Parent_LogIncome                       1.00
# Children_Per_Household                 1.00
# C(Year)[2017]                          1.00
# C(Year)[2018]                          1.00
# C(Year)[2019]                          1.00
# C(Year)[2020]                          1.00
# C(Year)[2021]                          1.00
# C(Year)[2022]                          1.00
# C(Year)[2023]                          1.00
# Central_Child_Age                      1.00
# Central_Child_Age2                     1.00
# Child_Age_CLogIncome                   1.00
# Child_Age2_CLogIncome                  1.00
# Central_Parent_Age                     1.00
# Central_Parent_Age2                    1.00
# 1|Region_sigma                         1.01
# Parent_LogIncome|Region_sigma          1.00
# 1|Region[ARMM]                         1.00
# 1|Region[CAR]                          1.00
# 1|Region[MIMAROPA]                     1.00
# 1|Region[NCR]                          1.00
# 1|Region[Region I]                     1.00
# 1|Region[Region II]                    1.00
# 1|Region[Region III]                   1.00
# 1|Region[Region IV-A]                  1.00
# 1|Region[Region IX]                    1.00
# 1|Region[Region V]                     1.00
# 1|Region[Region VI]                    1.00
# 1|Region[Region VII]                   1.00
# 1|Region[Region VIII]                  1.00
# 1|Region[Region X]                     1.00
# 1|Region[Region XI]                    1.00
# 1|Region[Region XII]                   1.00
# 1|Region[Region XIII]                  1.00
# Parent_LogIncome|Region[ARMM]          1.00
# Parent_LogIncome|Region[CAR]           1.00
# Parent_LogIncome|Region[MIMAROPA]      1.00
# Parent_LogIncome|Region[NCR]           1.00
# Parent_LogIncome|Region[Region I]      1.00
# Parent_LogIncome|Region[Region II]     1.00
# Parent_LogIncome|Region[Region III]    1.00
# Parent_LogIncome|Region[Region IV-A]   1.00
# Parent_LogIncome|Region[Region IX]     1.00
# Parent_LogIncome|Region[Region V]      1.00
# Parent_LogIncome|Region[Region VI]     1.00
# Parent_LogIncome|Region[Region VII]    1.00
# Parent_LogIncome|Region[Region VIII]   1.00
# Parent_LogIncome|Region[Region X]      1.00
# Parent_LogIncome|Region[Region XI]     1.00
# Parent_LogIncome|Region[Region XII]    1.00
# Parent_LogIncome|Region[Region XIII]   1.00

# %%
#Setting the Dataframe
df = complete_df.copy()

# Specify the prior for Parent_LogIncome
priors = {
    "Parent_LogIncome": bmb.Prior("Normal", mu=0.4, sigma=0.10)
}

# Update the formula to include new controls
formula = (
    "Child_LogIncome ~ Parent_LogIncome + Children_Per_Household + C(Year) "
    "+ Central_Child_Age + Central_Child_Age2 "
    "+ Child_Age_CLogIncome + Child_Age2_CLogIncome "
    "+ Central_Parent_Age + Central_Parent_Age2 "
    "+ (1 | Region)"
)

model = bmb.Model(formula, df, family="gaussian", priors=priors)

results1 = model.fit(
    draws=2000, tune=2000, random_seed=42, cores=1, chains=4, target_accept=0.995
)

# Show summary of selected parameters - with Random Slopes
print(az.summary(
    results1,
    var_names=[
        "~sigma", "~Intercept", "Parent_LogIncome", "Children_Per_Household", "C(Year)",
        "Central_Child_Age", "Central_Child_Age2", "Child_Age_CLogIncome", "Child_Age2_CLogIncome",
        "Central_Parent_Age", "Central_Parent_Age2"
    ]
))
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, Parent_LogIncome, Children_Per_Household, C(Year), Central_Child_Age, Central_Child_Age2, Child_Age_CLogIncome, Child_Age2_CLogIncome, Central_Parent_Age, Central_Parent_Age2, 1|Region_sigma, 1|Region_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 823 seconds.
#                          mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# Parent_LogIncome        0.393  0.010   0.375    0.412      0.000      0.0
# Children_Per_Household -0.027  0.003  -0.032   -0.022      0.000      0.0
# C(Year)[2017]          -0.008  0.020  -0.044    0.031      0.000      0.0
# C(Year)[2018]           0.064  0.020   0.030    0.103      0.000      0.0
# C(Year)[2019]           0.144  0.023   0.103    0.188      0.000      0.0
# C(Year)[2020]           0.148  0.021   0.111    0.188      0.000      0.0
# C(Year)[2021]           0.192  0.018   0.159    0.227      0.000      0.0
# C(Year)[2022]           0.193  0.018   0.160    0.226      0.000      0.0
# C(Year)[2023]           0.225  0.018   0.191    0.259      0.000      0.0
# Central_Child_Age      -0.003  0.001  -0.005   -0.000      0.000      0.0
# Central_Child_Age2     -0.001  0.000  -0.001   -0.000      0.000      0.0
# Child_Age_CLogIncome    0.008  0.002   0.004    0.011      0.000      0.0
# Child_Age2_CLogIncome  -0.001  0.000  -0.002    0.000      0.000      0.0
# Central_Parent_Age      0.007  0.002   0.003    0.011      0.000      0.0
# Central_Parent_Age2    -0.000  0.000  -0.001   -0.000      0.000      0.0
# 1|Region_sigma          0.083  0.017   0.053    0.115      0.000      0.0
# 1|Region[ARMM]         -0.058  0.042  -0.133    0.020      0.001      0.0
# 1|Region[CAR]           0.045  0.027  -0.008    0.095      0.001      0.0
# 1|Region[MIMAROPA]      0.018  0.029  -0.037    0.071      0.001      0.0
# 1|Region[NCR]           0.223  0.022   0.181    0.264      0.001      0.0
# 1|Region[Region I]     -0.085  0.029  -0.138   -0.030      0.001      0.0
# 1|Region[Region II]    -0.004  0.028  -0.056    0.048      0.001      0.0
# 1|Region[Region III]    0.034  0.024  -0.009    0.081      0.001      0.0
# 1|Region[Region IV-A]   0.081  0.025   0.033    0.126      0.001      0.0
# 1|Region[Region IX]    -0.008  0.031  -0.064    0.052      0.001      0.0
# 1|Region[Region V]     -0.047  0.028  -0.098    0.007      0.001      0.0
# 1|Region[Region VI]    -0.010  0.025  -0.056    0.037      0.001      0.0
# 1|Region[Region VII]    0.037  0.024  -0.007    0.085      0.001      0.0
# 1|Region[Region VIII]  -0.035  0.026  -0.083    0.016      0.001      0.0
# 1|Region[Region X]     -0.044  0.025  -0.092    0.005      0.001      0.0
# 1|Region[Region XI]    -0.030  0.028  -0.083    0.023      0.001      0.0
# 1|Region[Region XII]   -0.068  0.031  -0.126   -0.010      0.001      0.0
# 1|Region[Region XIII]  -0.041  0.028  -0.093    0.013      0.001      0.0
#
#                         ess_bulk  ess_tail  r_hat
# Parent_LogIncome          5308.0    4971.0    1.0
# Children_Per_Household    7305.0    5253.0    1.0
# C(Year)[2017]             3093.0    4435.0    1.0
# C(Year)[2018]             3074.0    4481.0    1.0
# C(Year)[2019]             3814.0    4941.0    1.0
# C(Year)[2020]             3323.0    4947.0    1.0
# C(Year)[2021]             2913.0    4815.0    1.0
# C(Year)[2022]             2753.0    4393.0    1.0
# C(Year)[2023]             2837.0    4625.0    1.0
# Central_Child_Age         6139.0    4973.0    1.0
# Central_Child_Age2        6868.0    5869.0    1.0
# Child_Age_CLogIncome      6581.0    5424.0    1.0
# Child_Age2_CLogIncome     5845.0    5709.0    1.0
# Central_Parent_Age        4825.0    5123.0    1.0
# Central_Parent_Age2       4823.0    5287.0    1.0
# 1|Region_sigma            1588.0    2633.0    1.0
# 1|Region[ARMM]            4101.0    5427.0    1.0
# 1|Region[CAR]             2002.0    3588.0    1.0
# 1|Region[MIMAROPA]        2327.0    4148.0    1.0
# 1|Region[NCR]             1366.0    2232.0    1.0
# 1|Region[Region I]        2363.0    4215.0    1.0
# 1|Region[Region II]       2049.0    3707.0    1.0
# 1|Region[Region III]      1580.0    2714.0    1.0
# 1|Region[Region IV-A]     1766.0    2997.0    1.0
# 1|Region[Region IX]       2613.0    3844.0    1.0
# 1|Region[Region V]        2229.0    3940.0    1.0
# 1|Region[Region VI]       1797.0    2900.0    1.0
# 1|Region[Region VII]      1716.0    2731.0    1.0
# 1|Region[Region VIII]     1983.0    3472.0    1.0
# 1|Region[Region X]        1842.0    3150.0    1.0
# 1|Region[Region XI]       2276.0    3919.0    1.0
# 1|Region[Region XII]      2482.0    4212.0    1.0
# 1|Region[Region XIII]     2352.0    4232.0    1.0

# %%
import arviz as az
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Extract posterior samples for group-level slopes
idata = results1  # Bambi returns an InferenceData object

# Get the names of the regions from the original data
regions = sorted(df['Region'].unique())

# Get the base (population-level) slope
base_slope = idata.posterior['Parent_LogIncome'].values  # shape (chain, draw)

# Get the group (region) specific slope offsets
# In Bambi/PyMC3, the group effect is named e.g. 'Parent_LogIncome|Region'
group_effect = idata.posterior['Parent_LogIncome|Region'].values  # shape (chain, draw, region)

# Compute the actual slope per region: population + group offset
n_chains, n_draws = base_slope.shape
n_regions = group_effect.shape[2]
region_slopes = {}

for i, region in enumerate(regions):
    # sum population-level slope and region offset at each posterior sample
    total_slope = base_slope + group_effect[:, :, i]
    total_slope = total_slope.reshape(-1)
    region_slopes[region] = total_slope

# Summarize into mean and 95% credible interval
summary = []
for region, samples in region_slopes.items():
    mean = np.mean(samples)
    hdi = az.hdi(samples, hdi_prob=0.95)
    summary.append({"Region": region, "Slope_mean": mean, "Slope_2.5%": hdi[0], "Slope_97.5%": hdi[1]})

slope_df = pd.DataFrame(summary)
print(slope_df)

# Plot
plt.figure(figsize=(10, 6))
plt.errorbar(
    slope_df["Region"],
    slope_df["Slope_mean"],
    yerr=[slope_df["Slope_mean"] - slope_df["Slope_2.5%"], slope_df["Slope_97.5%"] - slope_df["Slope_mean"]],
    fmt='o',
    capsize=5
)
plt.axhline(0, color='gray', linestyle='--')
plt.ylabel("Slope (Parent_LogIncome effect)")
plt.title("Posterior mean and 95% credible interval of slope per Region")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="font-family:monospace; font-size:18px;"><b>Hierarchical Modelling - Urban Only</b></span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import bambi as bmb
import arviz as az

# Use your complete_df as the dataset
df_urban = complete_df.copy()

# Filter for father-daughter pairs (Parent_Sex == 'Father', Child_Sex == 'Daughter')
df_urban = df_urban[(df_urban['Parent_Sex'] == 'Father') & (df_urban['Child_Sex'] == 'Daughter')]

# ✅ Filter for urban households only (Urban_Rural == 1)
df_urban = df_urban[df_urban['Urban_Rural'] == 1]

# Ensure Region is categorical
df_urban['Region'] = df_urban['Region'].astype('category')

# --- Sample size and counts after cleaning ---
print(f"Sample size after all cleaning and filtering: {df_urban.shape[0]}")
print("\nCounts by Region:")
print(df_urban['Region'].value_counts())
print("\nCounts by Year:")
print(df_urban['Year'].value_counts())

# --- Descriptive statistics for key variables ---
print("\nDescriptive stats for key variables:")
print(df_urban[['Child_LogIncome', 'Parent_LogIncome', 'Children_Per_Household', 'Child_Age']].describe())

# --- Missing data summary ---
print("\nMissing values by column:")
print(df_urban.isnull().sum())

# --- Distribution plot for Child_LogIncome ---
df_urban['Child_LogIncome'].hist()
plt.title('Distribution of Child_LogIncome')
plt.xlabel('Child_LogIncome')
plt.ylabel('Frequency')
plt.show()

# --- Counts by Parent_Education, if available ---
if 'Parent_Education' in df_urban.columns:
    print("\nCounts by Parent_Education:")
    print(df_urban['Parent_Education'].value_counts())

# --- Session information for reproducibility ---
print("\nSession Info:")
print(f"Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"Bambi: {bmb.__version__}")
print(f"ArviZ: {az.__version__}")

# Specify the prior for Parent_LogIncome
priors = {
    "Parent_LogIncome": bmb.Prior("Normal", mu=0.4, sigma=0.10)
}

# ---- Add new centralized controls to formula ----
formula = (
    "Child_LogIncome ~ Parent_LogIncome + Children_Per_Household + C(Year) "
    "+ Central_Child_Age + Central_Child_Age2 "
    "+ Child_Age_CLogIncome + Child_Age2_CLogIncome "
    "+ Central_Parent_Age + Central_Parent_Age2 "
    "+ (1 | Region)"
)

# Fit the model
model = bmb.Model(formula, df_urban, family="gaussian", priors=priors)

result_urban = model.fit(
    draws=2000, tune=2000, random_seed=42, cores=1, chains=4, target_accept=0.995
)

# Show summary of selected parameters
print(az.summary(
    result_urban,
    var_names=[
        "~sigma", "~Intercept", "Parent_LogIncome", "Children_Per_Household", "C(Year)",
        "Central_Child_Age", "Central_Child_Age2", "Child_Age_CLogIncome", "Child_Age2_CLogIncome",
        "Central_Parent_Age", "Central_Parent_Age2"
    ]
))
# Out:
# Sample size after all cleaning and filtering: 10746
#
# Counts by Region:
# Region
# NCR            4405
# Region III     1010
# Region VII      928
# Region IV-A     775
# Region VI       591
# Region X        571
# Region XI       405
# Region XII      295
# Region XIII     274
# Region VIII     274
# CAR             270
# MIMAROPA        259
# Region IX       235
# Region V        192
# Region II       118
# Region I        101
# ARMM             43
# Name: count, dtype: int64
#
# Counts by Year:
# Year
# 2022    2416
# 2023    2053
# 2021    2011
# 2018    1115
# 2017     946
# 2020     922
# 2016     695
# 2019     588
# Name: count, dtype: int64
#
# Descriptive stats for key variables:
#        Child_LogIncome  Parent_LogIncome  Children_Per_Household     Child_Age
# count     10746.000000      10746.000000            10746.000000  10746.000000
# mean          6.311025          6.300948                2.984645     28.380886
# std           0.526193          0.576196                1.516850      3.329550
# min           3.496508          3.218876                1.000000     25.000000
# 25%           5.991465          5.991465                2.000000     26.000000
# 50%           6.285998          6.214608                3.000000     27.000000
# 75%           6.684612          6.551080                4.000000     30.000000
# max           8.699515          9.903488               12.000000     45.000000
#
# Missing values by column:
# OrigHHNUM                        0
# Year                             0
# Quarter                          0
# Household_Number                 0
# Region                           0
# Urban_Rural                      0
# Children_Per_Household           0
# Parent_Sex                       0
# Child_Sex                        0
# Parent_Age                       0
# Child_Age                        0
# Parent_Marital_Status            0
# Child_Marital_Status             0
# Parent_Educational_Attainment    0
# Child_Educational_Attainment     0
# Parent_Schooling_Years           0
# Child_Schooling_Years            0
# Parent_Primary_Occupation        0
# Child_Primary_Occupation         0
# Parent_WagePerDay                0
# Child_WagePerDay                 0
# Child_Birth_Cohort               0
# Parent_LogIncome                 0
# Child_LogIncome                  0
# Birth_Cohort                     0
# Central_Child_Age                0
# Central_Child_Age2               0
# Central_Parent_LogIncome         0
# Child_Age_CLogIncome             0
# Child_Age2_CLogIncome            0
# Central_Parent_Age               0
# Central_Parent_Age2              0
# dtype: int64
# Session Info:
# Python: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# Pandas: 2.3.0
# Bambi: 0.15.0
# ArviZ: 0.21.0
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, Parent_LogIncome, Children_Per_Household, C(Year), Central_Child_Age, Central_Child_Age2, Child_Age_CLogIncome, Child_Age2_CLogIncome, Central_Parent_Age, Central_Parent_Age2, 1|Region_sigma, 1|Region_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 576 seconds.
#                          mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# Parent_LogIncome        0.373  0.011   0.351    0.394      0.000    0.000
# Children_Per_Household -0.025  0.003  -0.031   -0.020      0.000    0.000
# C(Year)[2017]          -0.007  0.023  -0.050    0.036      0.000    0.000
# C(Year)[2018]           0.039  0.022  -0.002    0.081      0.000    0.000
# C(Year)[2019]           0.116  0.025   0.067    0.162      0.000    0.000
# C(Year)[2020]           0.140  0.023   0.096    0.182      0.000    0.000
# C(Year)[2021]           0.167  0.020   0.130    0.205      0.000    0.000
# C(Year)[2022]           0.189  0.020   0.152    0.225      0.000    0.000
# C(Year)[2023]           0.206  0.020   0.168    0.243      0.000    0.000
# Central_Child_Age      -0.006  0.001  -0.009   -0.003      0.000    0.000
# Central_Child_Age2     -0.001  0.000  -0.001   -0.000      0.000    0.000
# Child_Age_CLogIncome    0.005  0.002   0.000    0.009      0.000    0.000
# Child_Age2_CLogIncome  -0.001  0.001  -0.002   -0.000      0.000    0.000
# Central_Parent_Age      0.009  0.002   0.004    0.013      0.000    0.000
# Central_Parent_Age2    -0.000  0.000  -0.001    0.000      0.000    0.000
# 1|Region_sigma          0.081  0.018   0.053    0.114      0.000    0.000
# 1|Region[ARMM]         -0.072  0.054  -0.172    0.030      0.001    0.001
# 1|Region[CAR]           0.066  0.032   0.006    0.128      0.001    0.000
# 1|Region[MIMAROPA]      0.007  0.033  -0.050    0.072      0.001    0.000
# 1|Region[NCR]           0.204  0.022   0.164    0.246      0.001    0.000
# 1|Region[Region I]     -0.074  0.044  -0.154    0.008      0.001    0.000
# 1|Region[Region II]     0.008  0.041  -0.067    0.087      0.001    0.000
# 1|Region[Region III]    0.015  0.024  -0.032    0.061      0.001    0.000
# 1|Region[Region IV-A]   0.082  0.026   0.034    0.130      0.001    0.000
# 1|Region[Region IX]    -0.034  0.033  -0.097    0.028      0.001    0.000
# 1|Region[Region V]     -0.026  0.035  -0.092    0.039      0.001    0.000
# 1|Region[Region VI]    -0.023  0.027  -0.075    0.025      0.001    0.000
# 1|Region[Region VII]    0.041  0.025  -0.006    0.088      0.001    0.000
# 1|Region[Region VIII]  -0.016  0.032  -0.076    0.045      0.001    0.000
# 1|Region[Region X]     -0.034  0.027  -0.083    0.019      0.001    0.000
# 1|Region[Region XI]    -0.033  0.029  -0.087    0.023      0.001    0.000
# 1|Region[Region XII]   -0.067  0.031  -0.123   -0.009      0.001    0.000
# 1|Region[Region XIII]  -0.046  0.032  -0.108    0.014      0.001    0.000
#
#                         ess_bulk  ess_tail  r_hat
# Parent_LogIncome          5643.0    5333.0    1.0
# Children_Per_Household    8429.0    6057.0    1.0
# C(Year)[2017]             2948.0    4707.0    1.0
# C(Year)[2018]             2753.0    4390.0    1.0
# C(Year)[2019]             3291.0    4970.0    1.0
# C(Year)[2020]             2892.0    4978.0    1.0
# C(Year)[2021]             2481.0    4341.0    1.0
# C(Year)[2022]             2493.0    4208.0    1.0
# C(Year)[2023]             2581.0    4339.0    1.0
# Central_Child_Age         7258.0    5710.0    1.0
# Central_Child_Age2        7810.0    5101.0    1.0
# Child_Age_CLogIncome      7105.0    5587.0    1.0
# Child_Age2_CLogIncome     6248.0    5382.0    1.0
# Central_Parent_Age        5074.0    5444.0    1.0
# Central_Parent_Age2       5250.0    5631.0    1.0
# 1|Region_sigma            2146.0    3580.0    1.0
# 1|Region[ARMM]            6323.0    5530.0    1.0
# 1|Region[CAR]             3264.0    4958.0    1.0
# 1|Region[MIMAROPA]        3163.0    4541.0    1.0
# 1|Region[NCR]             1650.0    2984.0    1.0
# 1|Region[Region I]        4995.0    5793.0    1.0
# 1|Region[Region II]       4552.0    5311.0    1.0
# 1|Region[Region III]      2087.0    3705.0    1.0
# 1|Region[Region IV-A]     2265.0    3663.0    1.0
# 1|Region[Region IX]       3375.0    4985.0    1.0
# 1|Region[Region V]        4108.0    5341.0    1.0
# 1|Region[Region VI]       2358.0    4024.0    1.0
# 1|Region[Region VII]      2107.0    3629.0    1.0
# 1|Region[Region VIII]     3249.0    4272.0    1.0
# 1|Region[Region X]        2282.0    4337.0    1.0
# 1|Region[Region XI]       2757.0    4178.0    1.0
# 1|Region[Region XII]      3209.0    4038.0    1.0
# 1|Region[Region XIII]     3104.0    4302.0    1.0

# %% [markdown]
# <span style="font-family:monospace; font-size:18px;"><b>Hierarchical Modelling - Rural Only</b></span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import bambi as bmb
import arviz as az

# Use your complete_df as the dataset
df_rural = complete_df.copy()

# Filter for father-daughter pairs (Parent_Sex == 'Father', Child_Sex == 'Daughter')
df_rural = df_rural[(df_rural['Parent_Sex'] == 'Father') & (df_rural['Child_Sex'] == 'Daughter')]

# ✅ Filter for rural households only (Urban_Rural == 2)
df_rural = df_rural[df_rural['Urban_Rural'] == 2]

# Ensure Region is categorical
df_rural['Region'] = df_rural['Region'].astype('category')

# --- Sample size and counts after cleaning ---
print(f"Sample size after all cleaning and filtering: {df_rural.shape[0]}")
print("\nCounts by Region:")
print(df_rural['Region'].value_counts())
print("\nCounts by Year:")
print(df_rural['Year'].value_counts())

# --- Descriptive statistics for key variables ---
print("\nDescriptive stats for key variables:")
print(df_rural[['Child_LogIncome', 'Parent_LogIncome', 'Children_Per_Household', 'Child_Age']].describe())

# --- Missing data summary ---
print("\nMissing values by column:")
print(df_rural.isnull().sum())

# --- Distribution plot for Child_LogIncome ---
df_rural['Child_LogIncome'].hist()
plt.title('Distribution of Child_LogIncome')
plt.xlabel('Child_LogIncome')
plt.ylabel('Frequency')
plt.show()

# --- Counts by Parent_Education, if available ---
if 'Parent_Education' in df_rural.columns:
    print("\nCounts by Parent_Education:")
    print(df_rural['Parent_Education'].value_counts())

# --- Session information for reproducibility ---
print("\nSession Info:")
print(f"Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"Bambi: {bmb.__version__}")
print(f"ArviZ: {az.__version__}")

# Specify the prior for Parent_LogIncome
priors = {
    "Parent_LogIncome": bmb.Prior("Normal", mu=0.4, sigma=0.10)
}

# Define the model formula
formula = (
    "Child_LogIncome ~ Parent_LogIncome + Children_Per_Household + C(Year) "
    "+ Central_Child_Age + Central_Child_Age2 "
    "+ Child_Age_CLogIncome + Child_Age2_CLogIncome "
    "+ Central_Parent_Age + Central_Parent_Age2 "
    "+ (1 | Region)"
)
# Fit the model
model = bmb.Model(formula, df_rural, family="gaussian", priors=priors)

result_rural = model.fit(
    draws=2000, tune=2000, random_seed=42, cores=1, chains=4, target_accept=0.995
)

# Show summary of selected parameters
print(az.summary(
    result_rural,
    var_names=[
        "~sigma", "~Intercept", "Parent_LogIncome", "Children_Per_Household", "C(Year)",
        "Central_Child_Age", "Central_Child_Age2", "Child_Age_CLogIncome", "Child_Age2_CLogIncome",
        "Central_Parent_Age", "Central_Parent_Age2"
    ]
))
# Out:
# Sample size after all cleaning and filtering: 5157
#
# Counts by Region:
# Region
# Region III     546
# Region VIII    477
# Region VI      471
# CAR            457
# Region II      441
# Region I       425
# Region V       378
# Region X       326
# Region VII     326
# Region IV-A    324
# Region XIII    250
# MIMAROPA       237
# Region IX      153
# Region XI      152
# Region XII     108
# ARMM            86
# NCR              0
# Name: count, dtype: int64
#
# Counts by Year:
# Year
# 2021    1046
# 2022     973
# 2023     884
# 2018     595
# 2017     573
# 2020     426
# 2016     356
# 2019     304
# Name: count, dtype: int64
#
# Descriptive stats for key variables:
#        Child_LogIncome  Parent_LogIncome  Children_Per_Household    Child_Age
# count      5157.000000       5157.000000             5157.000000  5157.000000
# mean          6.079015          6.085386                3.064185    28.282916
# std           0.648514          0.610305                1.602688     3.295630
# min           3.044522          2.484907                1.000000    25.000000
# 25%           5.703782          5.703782                2.000000    26.000000
# 50%           5.991465          5.991465                3.000000    27.000000
# 75%           6.579251          6.309918                4.000000    30.000000
# max           8.316545          9.104980               11.000000    45.000000
#
# Missing values by column:
# OrigHHNUM                        0
# Year                             0
# Quarter                          0
# Household_Number                 0
# Region                           0
# Urban_Rural                      0
# Children_Per_Household           0
# Parent_Sex                       0
# Child_Sex                        0
# Parent_Age                       0
# Child_Age                        0
# Parent_Marital_Status            0
# Child_Marital_Status             0
# Parent_Educational_Attainment    0
# Child_Educational_Attainment     0
# Parent_Schooling_Years           0
# Child_Schooling_Years            0
# Parent_Primary_Occupation        0
# Child_Primary_Occupation         0
# Parent_WagePerDay                0
# Child_WagePerDay                 0
# Child_Birth_Cohort               0
# Parent_LogIncome                 0
# Child_LogIncome                  0
# Birth_Cohort                     0
# Central_Child_Age                0
# Central_Child_Age2               0
# Central_Parent_LogIncome         0
# Child_Age_CLogIncome             0
# Child_Age2_CLogIncome            0
# Central_Parent_Age               0
# Central_Parent_Age2              0
# dtype: int64
# Session Info:
# Python: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# Pandas: 2.3.0
# Bambi: 0.15.0
# ArviZ: 0.21.0
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, Parent_LogIncome, Children_Per_Household, C(Year), Central_Child_Age, Central_Child_Age2, Child_Age_CLogIncome, Child_Age2_CLogIncome, Central_Parent_Age, Central_Parent_Age2, 1|Region_sigma, 1|Region_offset]
# Output()
