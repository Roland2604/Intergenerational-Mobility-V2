# %%
import pandas as pd

file_path = '/Users/rolanddelarosa/Desktop/THESIS VERSION 2/Cleaned Files 1/AgeFiltered_CleanedData.csv'

# Read just the header to get the column names
header = pd.read_csv(file_path, nrows=0)
col_names = header.columns

# Now use the column names at index 17 and 18
dtype_dict = {col_names[17]: str, col_names[18]: str}

# Now read the CSV with the dtype_dict applied
df = pd.read_csv(file_path, dtype=dtype_dict)

df.head()
# Out:
#    OrigHHNUM  Year  Quarter Household_Number  Region  Urban_Rural  \
# 0          4  2016        2           2/2/16       1            2
# 1          4  2016        2           2/2/16       1            2
# 2          5  2016        2           2/3/16       1            2
# 3          5  2016        2           2/3/16       1            2
# 4         10  2016        2           2/5/16       1            2
#
#    Children_Per_Household  Parent_Sex  Child_Sex  Parent_Age  ...  \
# 0                       2           1          1          51  ...
# 1                       2           2          1          51  ...
# 2                       1           1          1          71  ...
# 3                       1           2          1          54  ...
# 4                       1           1          1          72  ...
#
#    Child_Marital_Status  Parent_Educational_Attainment  \
# 0                     1                              5
# 1                     1                              9
# 2                     1                              2
# 3                     1                              2
# 4                     4                              3
#
#    Child_Educational_Attainment  Parent_Schooling_Years  \
# 0                             9                      10
# 1                             9                      14
# 2                             9                       4
# 3                             9                       2
# 4                             5                       6
#
#    Child_Schooling_Years  Parent_Primary_Occupation  Child_Primary_Occupation  \
# 0                     14                          1                       NaN
# 1                     14                        NaN                       NaN
# 2                     14                          9                         1
# 3                     14                          9                         1
# 4                     10                          6                         1
#
#   Parent_WagePerDay Child_WagePerDay Child_Birth_Cohort
# 0                                                  1990
# 1                                                  1990
# 2               350              909               1989
# 3               200              909               1989
# 4                                                  1977
#
# [5 rows x 22 columns]

# %% [markdown]
# <span style="font-family:monospace; font-size:15px;"><b>Age Cleaning and Adding Log Incomes</b></span>
#
#
# - Child Age (25-45)
# - Parent Age (45-64)
# - Natural Logarithmic of the Incomes
# - Adding the Birth_Cohort Groups
# - Filtering missing data of income (both parent & child)

# %%
import pandas as pd
import numpy as np

# Ensure numeric types
df['Parent_Age'] = pd.to_numeric(df['Parent_Age'], errors='coerce')
df['Child_Age'] = pd.to_numeric(df['Child_Age'], errors='coerce')
df['Parent_WagePerDay'] = pd.to_numeric(df['Parent_WagePerDay'], errors='coerce')
df['Child_WagePerDay'] = pd.to_numeric(df['Child_WagePerDay'], errors='coerce')

# Filter by age
filtered_df = df[(df['Parent_Age'] >= 45) & (df['Parent_Age'] <= 64) &
                 (df['Child_Age'] >= 25) & (df['Child_Age'] <= 45)].copy()

# Apply log (avoid log(0))
filtered_df['Parent_LogIncome'] = np.log(filtered_df['Parent_WagePerDay'].replace(0, np.nan))
filtered_df['Child_LogIncome'] = np.log(filtered_df['Child_WagePerDay'].replace(0, np.nan))

# Remove rows where either Parent or Child log income is missing
filtered_df = filtered_df.dropna(subset=['Parent_LogIncome', 'Child_LogIncome'])

# Define bins and labels for 5-year cohorts from 1970-1974 to 2000-2004
bins = [1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005]
labels = [
    '1970-1974',
    '1975-1979',
    '1980-1984',
    '1985-1989',
    '1990-1994',
    '1995-1999',
    '2000-2004'
]

# Assign cohorts to the filtered_df
filtered_df['Birth_Cohort'] = pd.cut(
    filtered_df['Child_Birth_Cohort'],
    bins=bins,
    labels=labels,
    right=False,          # left-inclusive: 1970 <= x < 1975 => '1970-1974'
    include_lowest=True
)

# Create descriptive frequency table for the filtered data
freq_table = filtered_df['Birth_Cohort'].value_counts(dropna=False).sort_index()
percent_table = filtered_df['Birth_Cohort'].value_counts(normalize=True, dropna=False).sort_index() * 100

descriptive_freq = pd.DataFrame({
    'Frequency': freq_table,
    'Percentage': percent_table.round(2)
})

print(descriptive_freq)
filtered_df.head()
# Out:
#               Frequency  Percentage
# Birth_Cohort
# 1970-1974            48        0.06
# 1975-1979           722        0.96
# 1980-1984          4161        5.51
# 1985-1989         15136       20.05
# 1990-1994         34187       45.28
# 1995-1999         21246       28.14
# 2000-2004             0        0.00
#     OrigHHNUM  Year  Quarter Household_Number  Region  Urban_Rural  \
# 3           5  2016        2           2/3/16       1            2
# 17         45  2016        2          2/14/16       1            2
# 18         45  2016        2          2/14/16       1            2
# 27         59  2016        2          2/19/16       1            2
# 35         63  2016        2          2/21/16       1            2
#
#     Children_Per_Household  Parent_Sex  Child_Sex  Parent_Age  ...  \
# 3                        1           2          1          54  ...
# 17                       2           1          1          54  ...
# 18                       2           2          1          54  ...
# 27                       2           2          2          46  ...
# 35                       2           2          1          58  ...
#
#     Parent_Schooling_Years  Child_Schooling_Years  Parent_Primary_Occupation  \
# 3                        2                     14                          9
# 17                       3                      6                          9
# 18                       6                      6                          9
# 27                      10                     12                          9
# 35                      12                     14                          5
#
#     Child_Primary_Occupation  Parent_WagePerDay  Child_WagePerDay  \
# 3                          1              200.0             909.0
# 17                         9              200.0             200.0
# 18                         9              200.0             200.0
# 27                         5              200.0             300.0
# 35                         5              454.0             423.0
#
#     Child_Birth_Cohort Parent_LogIncome Child_LogIncome  Birth_Cohort
# 3                 1989         5.298317        6.812345     1985-1989
# 17                1988         5.298317        5.298317     1985-1989
# 18                1988         5.298317        5.298317     1985-1989
# 27                1988         5.298317        5.703782     1985-1989
# 35                1982         6.118097        6.047372     1980-1984
#
# [5 rows x 25 columns]

# %%
import pandas as pd
import numpy as np

# --- Region and sex code mapping ---
region_map = {
    13: 'NCR', 14: 'CAR', 1: 'Region I', 2: 'Region II', 3: 'Region III', 4: 'Region IV-A',
    17: 'MIMAROPA', 5: 'Region V', 6: 'Region VI', 7: 'Region VII', 8: 'Region VIII',
    9: 'Region IX', 10: 'Region X', 11: 'Region XI', 12: 'Region XII', 16: 'Region XIII', 15: 'ARMM'
}
parent_sex_map = {1: 'Father', 2: 'Mother'}
child_sex_map = {1: 'Son', 2: 'Daughter'}

# --- Data cleaning: remove rows with missing parent/child income ---
# Assumes you have already created Parent_LogIncome and Child_LogIncome columns
complete_df = filtered_df.dropna(subset=['Parent_LogIncome', 'Child_LogIncome']).copy()

# Apply mappings
complete_df['Region'] = complete_df['Region'].map(region_map)
complete_df['Parent_Sex'] = complete_df['Parent_Sex'].map(parent_sex_map)
complete_df['Child_Sex'] = complete_df['Child_Sex'].map(child_sex_map)

# --- Count per group ---
sample_counts = (
    complete_df
    .groupby(['Region', 'Parent_Sex', 'Child_Sex'])
    .size()
    .reset_index(name='Samples_in_Investigation')
    .sort_values(['Region', 'Parent_Sex', 'Child_Sex'])
)

# --- Pivot to matrix style table ---
pivot_table = (
    sample_counts
    .pivot(index='Region', columns=['Parent_Sex', 'Child_Sex'], values='Samples_in_Investigation')
    .fillna(0).astype(int)
)

# --- Total per region (all pairs) ---
region_totals = (
    complete_df.groupby('Region').size().rename('Total_Region').to_frame()
)

# --- Total per sex pair (all regions) ---
pair_totals = (
    complete_df.groupby(['Parent_Sex', 'Child_Sex']).size().rename('Total_Pair').to_frame()
)

# --- Display tables ---
print("\nSAMPLES PER REGION AND PARENT/CHILD SEX PAIR:")
print(pivot_table)

print("\nTOTAL COMPLETE SAMPLES PER REGION (all pairs):")
print(region_totals)

print("\nTOTAL COMPLETE SAMPLES PER SEX PAIR (all regions):")
print(pair_totals)
# Out:
# SAMPLES PER REGION AND PARENT/CHILD SEX PAIR:
# Parent_Sex    Father         Mother
# Child_Sex   Daughter   Son Daughter   Son
# Region
# ARMM             129   280      140   190
# CAR              727  1341      870  1311
# MIMAROPA         496   907      519   728
# NCR             4405  5977     2866  3921
# Region I         526  1222      501  1157
# Region II        559  1131      638  1252
# Region III      1556  2761     1023  1831
# Region IV-A     1099  1643      765  1168
# Region IX        388   687      328   480
# Region V         570  1083      543   808
# Region VI       1062  1726      975  1544
# Region VII      1254  1765      906  1271
# Region VIII      751  1277      705  1035
# Region X         897  1551      704  1148
# Region XI        557  1327      447   832
# Region XII       403   802      374   731
# Region XIII      524  1070      495   841
#
# TOTAL COMPLETE SAMPLES PER REGION (all pairs):
#              Total_Region
# Region
# ARMM                  739
# CAR                  4249
# MIMAROPA             2650
# NCR                 17169
# Region I             3406
# Region II            3580
# Region III           7171
# Region IV-A          4675
# Region IX            1883
# Region V             3004
# Region VI            5307
# Region VII           5196
# Region VIII          3768
# Region X             4300
# Region XI            3163
# Region XII           2310
# Region XIII          2930
#
# TOTAL COMPLETE SAMPLES PER SEX PAIR (all regions):
#                       Total_Pair
# Parent_Sex Child_Sex
# Father     Daughter        15903
#            Son             26550
# Mother     Daughter        12799
#            Son             20248

# %%
import pandas as pd

# Use your complete_df as the dataset
complete_df = complete_df.copy()

# Filter for mother-son pairs (Parent_Sex == 'Mother', Child_Sex == 'Son')
complete_df = complete_df[(complete_df['Parent_Sex'] == 'Mother') & (complete_df['Child_Sex'] == 'Son')]

# Ensure Region is categorical
complete_df['Region'] = complete_df['Region'].astype('category')

# Centralize child age to 30
complete_df['Central_Child_Age'] = complete_df['Child_Age'] - 30

# Squared centralized child age
complete_df['Central_Child_Age2'] = complete_df['Central_Child_Age'] ** 2

# Centralize parent log income by its mean
mean_parent_log_income = complete_df['Parent_LogIncome'].mean()
complete_df['Central_Parent_LogIncome'] = complete_df['Parent_LogIncome'] - mean_parent_log_income

# Child_Age_CLogIncome: Central_Child_Age * Centralized Parent_LogIncome
complete_df['Child_Age_CLogIncome'] = complete_df['Central_Child_Age'] * complete_df['Central_Parent_LogIncome']

# Child_Age^2_CLogIncome: Central_Child_Age^2 * Centralized Parent_LogIncome
complete_df['Child_Age2_CLogIncome'] = complete_df['Central_Child_Age2'] * complete_df['Central_Parent_LogIncome']

# Centralize parent age to 50
complete_df['Central_Parent_Age'] = complete_df['Parent_Age'] - 50

# Squared centralized parent age
complete_df['Central_Parent_Age2'] = complete_df['Central_Parent_Age'] ** 2

complete_df.head()
# Out:
#      OrigHHNUM  Year  Quarter Household_Number    Region  Urban_Rural  \
# 3            5  2016        2           2/3/16  Region I            2
# 18          45  2016        2          2/14/16  Region I            2
# 35          63  2016        2          2/21/16  Region I            2
# 85         176  2016        2       2016-02-56  Region I            2
# 105        228  2016        2       2016-02-69  Region I            2
#
#      Children_Per_Household Parent_Sex Child_Sex  Parent_Age  ...  \
# 3                         1     Mother       Son          54  ...
# 18                        2     Mother       Son          54  ...
# 35                        2     Mother       Son          58  ...
# 85                        2     Mother       Son          54  ...
# 105                       7     Mother       Son          54  ...
#
#      Parent_LogIncome  Child_LogIncome  Birth_Cohort  Central_Child_Age  \
# 3            5.298317         6.812345     1985-1989                 -3
# 18           5.298317         5.298317     1985-1989                 -2
# 35           6.118097         6.047372     1980-1984                  4
# 85           6.525030         5.789960     1985-1989                 -1
# 105          5.857933         7.149132     1985-1989                 -1
#
#      Central_Child_Age2  Central_Parent_LogIncome  Child_Age_CLogIncome  \
# 3                     9                 -0.643565              1.930694
# 18                    4                 -0.643565              1.287130
# 35                   16                  0.176215              0.704860
# 85                    1                  0.583148             -0.583148
# 105                   1                 -0.083949              0.083949
#
#     Child_Age2_CLogIncome Central_Parent_Age  Central_Parent_Age2
# 3               -5.792083                  4                   16
# 18              -2.574259                  4                   16
# 35               2.819441                  8                   64
# 85               0.583148                  4                   16
# 105             -0.083949                  4                   16
#
# [5 rows x 32 columns]

# %% [markdown]
# <span style="font-family:monospace; font-size:18px;"><b>Income Bayesian Multilevel/Hierarchical Modelling</b></span>

# %%
# If not installed, uncomment and run:
# %pip install bambi pymc arviz

import pandas as pd
import bambi as bmb
import arviz as az

# %%
#Setting the Dataframe
df = complete_df.copy()

# Specify the prior for Parent_LogIncome
priors = {
    "Parent_LogIncome": bmb.Prior("Normal", mu=0.4, sigma=0.10)
}

# Update the formula to include new controls
formula = (
    "Child_LogIncome ~ Parent_LogIncome + Children_Per_Household + C(Year) "
    "+ Central_Child_Age + Central_Child_Age2 "
    "+ Child_Age_CLogIncome + Child_Age2_CLogIncome "
    "+ Central_Parent_Age + Central_Parent_Age2 "
    "+ (1 + Parent_LogIncome | Region)"
)

model = bmb.Model(formula, df, family="gaussian", priors=priors)

results1 = model.fit(
    draws=2000, tune=2000, random_seed=42, cores=1, chains=4, target_accept=0.995
)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, Parent_LogIncome, Children_Per_Household, C(Year), Central_Child_Age, Central_Child_Age2, Child_Age_CLogIncome, Child_Age2_CLogIncome, Central_Parent_Age, Central_Parent_Age2, 1|Region_sigma, 1|Region_offset, Parent_LogIncome|Region_sigma, Parent_LogIncome|Region_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 8266 seconds.

# %%
# Show summary of selected parameters
print(az.summary(
    results1,
    var_names=[
        "~sigma", "~Intercept", "Parent_LogIncome", "Children_Per_Household", "C(Year)",
        "Central_Child_Age", "Central_Child_Age2", "Child_Age_CLogIncome", "Child_Age2_CLogIncome",
        "Central_Parent_Age", "Central_Parent_Age2"
    ]
))
# Out:
#                                        mean     sd  hdi_3%  hdi_97%  \
# Parent_LogIncome                      0.365  0.012   0.344    0.387
# Children_Per_Household               -0.014  0.002  -0.018   -0.010
# C(Year)[2017]                         0.036  0.016   0.007    0.068
# C(Year)[2018]                         0.086  0.016   0.056    0.115
# C(Year)[2019]                         0.148  0.018   0.111    0.181
# C(Year)[2020]                         0.189  0.016   0.159    0.220
# C(Year)[2021]                         0.209  0.014   0.181    0.235
# C(Year)[2022]                         0.226  0.014   0.201    0.254
# C(Year)[2023]                         0.268  0.014   0.242    0.295
# Central_Child_Age                     0.001  0.001  -0.001    0.003
# Central_Child_Age2                   -0.001  0.000  -0.001   -0.000
# Child_Age_CLogIncome                  0.001  0.001  -0.001    0.004
# Child_Age2_CLogIncome                -0.001  0.000  -0.001   -0.000
# Central_Parent_Age                    0.006  0.001   0.003    0.009
# Central_Parent_Age2                  -0.000  0.000  -0.001   -0.000
# 1|Region_sigma                        0.305  0.069   0.189    0.435
# Parent_LogIncome|Region_sigma         0.041  0.010   0.024    0.060
# 1|Region[ARMM]                       -0.352  0.161  -0.642   -0.038
# 1|Region[CAR]                        -0.137  0.117  -0.350    0.089
# 1|Region[MIMAROPA]                    0.239  0.131   0.005    0.497
# 1|Region[NCR]                         0.509  0.100   0.315    0.689
# 1|Region[Region I]                    0.223  0.117   0.007    0.439
# 1|Region[Region II]                  -0.108  0.113  -0.325    0.098
# 1|Region[Region III]                  0.276  0.110   0.070    0.481
# 1|Region[Region IV-A]                 0.216  0.117  -0.000    0.445
# 1|Region[Region IX]                  -0.194  0.127  -0.431    0.042
# 1|Region[Region V]                    0.169  0.117  -0.048    0.394
# 1|Region[Region VI]                   0.108  0.106  -0.090    0.308
# 1|Region[Region VII]                  0.146  0.115  -0.070    0.355
# 1|Region[Region VIII]                -0.264  0.112  -0.484   -0.064
# 1|Region[Region X]                   -0.285  0.114  -0.505   -0.076
# 1|Region[Region XI]                  -0.158  0.126  -0.396    0.075
# 1|Region[Region XII]                 -0.458  0.137  -0.715   -0.202
# 1|Region[Region XIII]                 0.078  0.119  -0.154    0.295
# Parent_LogIncome|Region[ARMM]         0.039  0.026  -0.009    0.087
# Parent_LogIncome|Region[CAR]          0.027  0.018  -0.008    0.059
# Parent_LogIncome|Region[MIMAROPA]    -0.054  0.021  -0.093   -0.015
# Parent_LogIncome|Region[NCR]         -0.033  0.014  -0.061   -0.007
# Parent_LogIncome|Region[Region I]    -0.040  0.018  -0.075   -0.007
# Parent_LogIncome|Region[Region II]    0.018  0.017  -0.015    0.050
# Parent_LogIncome|Region[Region III]  -0.029  0.017  -0.059    0.002
# Parent_LogIncome|Region[Region IV-A] -0.008  0.018  -0.040    0.027
# Parent_LogIncome|Region[Region IX]    0.017  0.020  -0.019    0.056
# Parent_LogIncome|Region[Region V]    -0.031  0.018  -0.064    0.004
# Parent_LogIncome|Region[Region VI]   -0.027  0.016  -0.057    0.004
# Parent_LogIncome|Region[Region VII]  -0.018  0.018  -0.053    0.014
# Parent_LogIncome|Region[Region VIII]  0.033  0.017  -0.000    0.064
# Parent_LogIncome|Region[Region X]     0.036  0.017   0.005    0.069
# Parent_LogIncome|Region[Region XI]    0.025  0.020  -0.015    0.060
# Parent_LogIncome|Region[Region XII]   0.062  0.022   0.022    0.103
# Parent_LogIncome|Region[Region XIII] -0.017  0.018  -0.053    0.016
#
#                                       mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# Parent_LogIncome                          0.000    0.000    2447.0    3337.0
# Children_Per_Household                    0.000    0.000   14327.0    5367.0
# C(Year)[2017]                             0.000    0.000    3703.0    5478.0
# C(Year)[2018]                             0.000    0.000    3635.0    5625.0
# C(Year)[2019]                             0.000    0.000    4087.0    5139.0
# C(Year)[2020]                             0.000    0.000    3775.0    5119.0
# C(Year)[2021]                             0.000    0.000    2981.0    5264.0
# C(Year)[2022]                             0.000    0.000    3061.0    4923.0
# C(Year)[2023]                             0.000    0.000    3004.0    5314.0
# Central_Child_Age                         0.000    0.000   12573.0    6926.0
# Central_Child_Age2                        0.000    0.000   12287.0    6805.0
# Child_Age_CLogIncome                      0.000    0.000   12246.0    6607.0
# Child_Age2_CLogIncome                     0.000    0.000   11822.0    6178.0
# Central_Parent_Age                        0.000    0.000    8903.0    6056.0
# Central_Parent_Age2                       0.000    0.000    9133.0    6031.0
# 1|Region_sigma                            0.001    0.001    2314.0    3700.0
# Parent_LogIncome|Region_sigma             0.000    0.000    2730.0    4051.0
# 1|Region[ARMM]                            0.003    0.002    4011.0    5460.0
# 1|Region[CAR]                             0.002    0.001    4060.0    4959.0
# 1|Region[MIMAROPA]                        0.002    0.001    4118.0    5798.0
# 1|Region[NCR]                             0.002    0.001    3081.0    5076.0
# 1|Region[Region I]                        0.002    0.001    3851.0    5418.0
# 1|Region[Region II]                       0.002    0.001    3448.0    5291.0
# 1|Region[Region III]                      0.002    0.001    3312.0    4782.0
# 1|Region[Region IV-A]                     0.002    0.001    3627.0    4895.0
# 1|Region[Region IX]                       0.002    0.001    4102.0    5743.0
# 1|Region[Region V]                        0.002    0.001    3655.0    5174.0
# 1|Region[Region VI]                       0.002    0.001    3153.0    4774.0
# 1|Region[Region VII]                      0.002    0.001    3463.0    5547.0
# 1|Region[Region VIII]                     0.002    0.001    3699.0    5121.0
# 1|Region[Region X]                        0.002    0.001    3860.0    4904.0
# 1|Region[Region XI]                       0.002    0.001    4187.0    5146.0
# 1|Region[Region XII]                      0.002    0.001    4375.0    5903.0
# 1|Region[Region XIII]                     0.002    0.001    3855.0    5220.0
# Parent_LogIncome|Region[ARMM]             0.000    0.000    4576.0    5228.0
# Parent_LogIncome|Region[CAR]              0.000    0.000    4839.0    5510.0
# Parent_LogIncome|Region[MIMAROPA]         0.000    0.000    4988.0    5023.0
# Parent_LogIncome|Region[NCR]              0.000    0.000    3520.0    5099.0
# Parent_LogIncome|Region[Region I]         0.000    0.000    4735.0    5111.0
# Parent_LogIncome|Region[Region II]        0.000    0.000    4085.0    5516.0
# Parent_LogIncome|Region[Region III]       0.000    0.000    4116.0    5289.0
# Parent_LogIncome|Region[Region IV-A]      0.000    0.000    4748.0    5276.0
# Parent_LogIncome|Region[Region IX]        0.000    0.000    5289.0    5621.0
# Parent_LogIncome|Region[Region V]         0.000    0.000    4658.0    5542.0
# Parent_LogIncome|Region[Region VI]        0.000    0.000    3984.0    5031.0
# Parent_LogIncome|Region[Region VII]       0.000    0.000    4882.0    5528.0
# Parent_LogIncome|Region[Region VIII]      0.000    0.000    4310.0    5519.0
# Parent_LogIncome|Region[Region X]         0.000    0.000    4934.0    5941.0
# Parent_LogIncome|Region[Region XI]        0.000    0.000    5068.0    5001.0
# Parent_LogIncome|Region[Region XII]       0.000    0.000    4854.0    6053.0
# Parent_LogIncome|Region[Region XIII]      0.000    0.000    4214.0    5384.0
#
#                                       r_hat
# Parent_LogIncome                        1.0
# Children_Per_Household                  1.0
# C(Year)[2017]                           1.0
# C(Year)[2018]                           1.0
# C(Year)[2019]                           1.0
# C(Year)[2020]                           1.0
# C(Year)[2021]                           1.0
# C(Year)[2022]                           1.0
# C(Year)[2023]                           1.0
# Central_Child_Age                       1.0
# Central_Child_Age2                      1.0
# Child_Age_CLogIncome                    1.0
# Child_Age2_CLogIncome                   1.0
# Central_Parent_Age                      1.0
# Central_Parent_Age2                     1.0
# 1|Region_sigma                          1.0
# Parent_LogIncome|Region_sigma           1.0
# 1|Region[ARMM]                          1.0
# 1|Region[CAR]                           1.0
# 1|Region[MIMAROPA]                      1.0
# 1|Region[NCR]                           1.0
# 1|Region[Region I]                      1.0
# 1|Region[Region II]                     1.0
# 1|Region[Region III]                    1.0
# 1|Region[Region IV-A]                   1.0
# 1|Region[Region IX]                     1.0
# 1|Region[Region V]                      1.0
# 1|Region[Region VI]                     1.0
# 1|Region[Region VII]                    1.0
# 1|Region[Region VIII]                   1.0
# 1|Region[Region X]                      1.0
# 1|Region[Region XI]                     1.0
# 1|Region[Region XII]                    1.0
# 1|Region[Region XIII]                   1.0
# Parent_LogIncome|Region[ARMM]           1.0
# Parent_LogIncome|Region[CAR]            1.0
# Parent_LogIncome|Region[MIMAROPA]       1.0
# Parent_LogIncome|Region[NCR]            1.0
# Parent_LogIncome|Region[Region I]       1.0
# Parent_LogIncome|Region[Region II]      1.0
# Parent_LogIncome|Region[Region III]     1.0
# Parent_LogIncome|Region[Region IV-A]    1.0
# Parent_LogIncome|Region[Region IX]      1.0
# Parent_LogIncome|Region[Region V]       1.0
# Parent_LogIncome|Region[Region VI]      1.0
# Parent_LogIncome|Region[Region VII]     1.0
# Parent_LogIncome|Region[Region VIII]    1.0
# Parent_LogIncome|Region[Region X]       1.0
# Parent_LogIncome|Region[Region XI]      1.0
# Parent_LogIncome|Region[Region XII]     1.0
# Parent_LogIncome|Region[Region XIII]    1.0

# %%
import arviz as az
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Extract posterior samples for group-level slopes
idata = results1  # Bambi returns an InferenceData object

# Get the names of the regions from the original data
regions = sorted(df['Region'].unique())

# Get the base (population-level) slope
base_slope = idata.posterior['Parent_LogIncome'].values  # shape (chain, draw)

# Get the group (region) specific slope offsets
# In Bambi/PyMC3, the group effect is named e.g. 'Parent_LogIncome|Region'
group_effect = idata.posterior['Parent_LogIncome|Region'].values  # shape (chain, draw, region)

# Compute the actual slope per region: population + group offset
n_chains, n_draws = base_slope.shape
n_regions = group_effect.shape[2]
region_slopes = {}

for i, region in enumerate(regions):
    # sum population-level slope and region offset at each posterior sample
    total_slope = base_slope + group_effect[:, :, i]
    total_slope = total_slope.reshape(-1)
    region_slopes[region] = total_slope

# Summarize into mean and 95% credible interval
summary = []
for region, samples in region_slopes.items():
    mean = np.mean(samples)
    hdi = az.hdi(samples, hdi_prob=0.95)
    summary.append({"Region": region, "Slope_mean": mean, "Slope_2.5%": hdi[0], "Slope_97.5%": hdi[1]})

slope_df = pd.DataFrame(summary)
print(slope_df)

# Plot
plt.figure(figsize=(10, 6))
plt.errorbar(
    slope_df["Region"],
    slope_df["Slope_mean"],
    yerr=[slope_df["Slope_mean"] - slope_df["Slope_2.5%"], slope_df["Slope_97.5%"] - slope_df["Slope_mean"]],
    fmt='o',
    capsize=5
)
plt.axhline(0, color='gray', linestyle='--')
plt.ylabel("Slope (Parent_LogIncome effect)")
plt.title("Posterior mean and 95% credible interval of slope per Region")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#          Region  Slope_mean  Slope_2.5%  Slope_97.5%
# 0          ARMM    0.404085    0.351968     0.452888
# 1           CAR    0.392121    0.361026     0.423174
# 2      MIMAROPA    0.310962    0.272490     0.346434
# 3           NCR    0.332219    0.311474     0.353382
# 4      Region I    0.325273    0.292457     0.353824
# 5     Region II    0.383060    0.352861     0.412131
# 6    Region III    0.336740    0.309407     0.362927
# 7   Region IV-A    0.356835    0.326163     0.389036
# 8     Region IX    0.382257    0.346116     0.417954
# 9      Region V    0.334351    0.301920     0.363981
# 10    Region VI    0.337927    0.311412     0.363810
# 11   Region VII    0.347418    0.316292     0.377485
# 12  Region VIII    0.398209    0.369003     0.427022
# 13     Region X    0.401759    0.371715     0.431985
# 14    Region XI    0.389839    0.354300     0.425860
# 15   Region XII    0.427118    0.384595     0.467765
# 16  Region XIII    0.348546    0.317578     0.381108

# %% [markdown]
# <span style="font-family:monospace; font-size:18px;"><b>Hierarchical Modelling - Urban Only</b></span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import bambi as bmb
import arviz as az

# Use your complete_df as the dataset
df_urban = complete_df.copy()

# Filter for mother-son pairs (Parent_Sex == 'Mother', Child_Sex == 'Son')
df_urban = df_urban[(df_urban['Parent_Sex'] == 'Mother') & (df_urban['Child_Sex'] == 'Son')]

# ✅ Filter for urban households only (Urban_Rural == 1)
df_urban = df_urban[df_urban['Urban_Rural'] == 1]

# Ensure Region is categorical
df_urban['Region'] = df_urban['Region'].astype('category')

# --- Sample size and counts after cleaning ---
print(f"Sample size after all cleaning and filtering: {df_urban.shape[0]}")
print("\nCounts by Region:")
print(df_urban['Region'].value_counts())
print("\nCounts by Year:")
print(df_urban['Year'].value_counts())

# --- Descriptive statistics for key variables ---
print("\nDescriptive stats for key variables:")
print(df_urban[['Child_LogIncome', 'Parent_LogIncome', 'Children_Per_Household', 'Child_Age']].describe())

# --- Missing data summary ---
print("\nMissing values by column:")
print(df_urban.isnull().sum())

# --- Distribution plot for Child_LogIncome ---
df_urban['Child_LogIncome'].hist()
plt.title('Distribution of Child_LogIncome')
plt.xlabel('Child_LogIncome')
plt.ylabel('Frequency')
plt.show()

# --- Counts by Parent_Education, if available ---
if 'Parent_Education' in df_urban.columns:
    print("\nCounts by Parent_Education:")
    print(df_urban['Parent_Education'].value_counts())

# --- Session information for reproducibility ---
print("\nSession Info:")
print(f"Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"Bambi: {bmb.__version__}")
print(f"ArviZ: {az.__version__}")

# Specify the prior for Parent_LogIncome
priors = {
    "Parent_LogIncome": bmb.Prior("Normal", mu=0.4, sigma=0.10)
}

# ---- Add new centralized controls to formula ----
formula = (
    "Child_LogIncome ~ Parent_LogIncome + Children_Per_Household + C(Year) "
    "+ Central_Child_Age + Central_Child_Age2 "
    "+ Child_Age_CLogIncome + Child_Age2_CLogIncome "
    "+ Central_Parent_Age + Central_Parent_Age2 "
    "+ (1 + Parent_LogIncome | Region)"
)

# Fit the model
model = bmb.Model(formula, df_urban, family="gaussian", priors=priors)

result_urban = model.fit(
    draws=2000, tune=2000, random_seed=42, cores=1, chains=4, target_accept=0.995
)

# Show summary of selected parameters
print(az.summary(
    result_urban,
    var_names=[
        "~sigma", "~Intercept", "Parent_LogIncome", "Children_Per_Household", "C(Year)",
        "Central_Child_Age", "Central_Child_Age2", "Child_Age_CLogIncome", "Child_Age2_CLogIncome",
        "Central_Parent_Age", "Central_Parent_Age2"
    ]
))
# Out:
# Sample size after all cleaning and filtering: 11225
#
# Counts by Region:
# Region
# NCR            3921
# Region III     1098
# Region VII      855
# Region IV-A     785
# Region VI       727
# Region X        632
# Region XI       527
# Region XII      456
# Region XIII     398
# CAR             344
# MIMAROPA        291
# Region VIII     274
# Region IX       254
# Region V        224
# Region II       204
# Region I        170
# ARMM             65
# Name: count, dtype: int64
#
# Counts by Year:
# Year
# 2022    2497
# 2023    2194
# 2021    2133
# 2018    1115
# 2020    1056
# 2017     967
# 2016     706
# 2019     557
# Name: count, dtype: int64
#
# Descriptive stats for key variables:
#        Child_LogIncome  Parent_LogIncome  Children_Per_Household     Child_Age
# count     11225.000000      11225.000000            11225.000000  11225.000000
# mean          6.221904          6.085345                2.882138     29.163742
# std           0.539909          0.778040                1.508974      3.817083
# min           2.995732          2.772589                1.000000     25.000000
# 25%           5.886104          5.634790                2.000000     26.000000
# 50%           6.214608          6.013715                3.000000     28.000000
# 75%           6.539586          6.597146                4.000000     31.000000
# max           9.903488          9.433484               13.000000     45.000000
#
# Missing values by column:
# OrigHHNUM                        0
# Year                             0
# Quarter                          0
# Household_Number                 0
# Region                           0
# Urban_Rural                      0
# Children_Per_Household           0
# Parent_Sex                       0
# Child_Sex                        0
# Parent_Age                       0
# Child_Age                        0
# Parent_Marital_Status            0
# Child_Marital_Status             0
# Parent_Educational_Attainment    0
# Child_Educational_Attainment     0
# Parent_Schooling_Years           0
# Child_Schooling_Years            0
# Parent_Primary_Occupation        0
# Child_Primary_Occupation         0
# Parent_WagePerDay                0
# Child_WagePerDay                 0
# Child_Birth_Cohort               0
# Parent_LogIncome                 0
# Child_LogIncome                  0
# Birth_Cohort                     0
# Central_Child_Age                0
# Central_Child_Age2               0
# Central_Parent_LogIncome         0
# Child_Age_CLogIncome             0
# Child_Age2_CLogIncome            0
# Central_Parent_Age               0
# Central_Parent_Age2              0
# dtype: int64
# Session Info:
# Python: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# Pandas: 2.3.0
# Bambi: 0.15.0
# ArviZ: 0.21.0
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, Parent_LogIncome, Children_Per_Household, C(Year), Central_Child_Age, Central_Child_Age2, Child_Age_CLogIncome, Child_Age2_CLogIncome, Central_Parent_Age, Central_Parent_Age2, 1|Region_sigma, 1|Region_offset, Parent_LogIncome|Region_sigma, Parent_LogIncome|Region_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 2737 seconds.
#                                        mean     sd  hdi_3%  hdi_97%  \
# Parent_LogIncome                      0.346  0.008   0.330    0.361
# Children_Per_Household               -0.017  0.003  -0.022   -0.012
# C(Year)[2017]                        -0.025  0.021  -0.063    0.016
# C(Year)[2018]                         0.036  0.021  -0.002    0.076
# C(Year)[2019]                         0.101  0.025   0.055    0.148
# C(Year)[2020]                         0.126  0.021   0.086    0.165
# C(Year)[2021]                         0.148  0.019   0.113    0.184
# C(Year)[2022]                         0.173  0.018   0.138    0.208
# C(Year)[2023]                         0.206  0.019   0.171    0.241
# Central_Child_Age                    -0.002  0.001  -0.004    0.001
# Central_Child_Age2                   -0.001  0.000  -0.001   -0.000
# Child_Age_CLogIncome                  0.002  0.002  -0.001    0.005
# Child_Age2_CLogIncome                -0.001  0.000  -0.002   -0.001
# Central_Parent_Age                    0.005  0.002   0.001    0.008
# Central_Parent_Age2                  -0.000  0.000  -0.000    0.000
# 1|Region_sigma                        0.129  0.040   0.072    0.201
# Parent_LogIncome|Region_sigma         0.009  0.007   0.000    0.022
# 1|Region[ARMM]                       -0.052  0.079  -0.202    0.090
# 1|Region[CAR]                         0.079  0.072  -0.041    0.225
# 1|Region[MIMAROPA]                   -0.098  0.070  -0.221    0.040
# 1|Region[NCR]                         0.275  0.054   0.177    0.386
# 1|Region[Region I]                   -0.060  0.068  -0.193    0.063
# 1|Region[Region II]                  -0.045  0.067  -0.176    0.084
# 1|Region[Region III]                  0.128  0.071   0.010    0.269
# 1|Region[Region IV-A]                 0.127  0.061   0.003    0.234
# 1|Region[Region IX]                  -0.088  0.063  -0.208    0.032
# 1|Region[Region V]                   -0.032  0.065  -0.160    0.092
# 1|Region[Region VI]                  -0.030  0.059  -0.136    0.090
# 1|Region[Region VII]                  0.068  0.063  -0.040    0.197
# 1|Region[Region VIII]                -0.029  0.071  -0.163    0.100
# 1|Region[Region X]                   -0.102  0.074  -0.257    0.014
# 1|Region[Region XI]                  -0.040  0.068  -0.171    0.077
# 1|Region[Region XII]                 -0.132  0.075  -0.276   -0.003
# 1|Region[Region XIII]                 0.004  0.064  -0.118    0.127
# Parent_LogIncome|Region[ARMM]         0.003  0.010  -0.015    0.024
# Parent_LogIncome|Region[CAR]         -0.003  0.010  -0.025    0.013
# Parent_LogIncome|Region[MIMAROPA]    -0.006  0.010  -0.028    0.010
# Parent_LogIncome|Region[NCR]         -0.002  0.008  -0.018    0.012
# Parent_LogIncome|Region[Region I]    -0.003  0.009  -0.024    0.013
# Parent_LogIncome|Region[Region II]    0.001  0.009  -0.017    0.018
# Parent_LogIncome|Region[Region III]  -0.006  0.011  -0.028    0.010
# Parent_LogIncome|Region[Region IV-A]  0.004  0.009  -0.010    0.024
# Parent_LogIncome|Region[Region IX]   -0.000  0.009  -0.018    0.017
# Parent_LogIncome|Region[Region V]     0.000  0.009  -0.017    0.019
# Parent_LogIncome|Region[Region VI]   -0.003  0.009  -0.022    0.011
# Parent_LogIncome|Region[Region VII]  -0.004  0.009  -0.024    0.011
# Parent_LogIncome|Region[Region VIII]  0.004  0.010  -0.012    0.025
# Parent_LogIncome|Region[Region X]     0.007  0.011  -0.008    0.030
# Parent_LogIncome|Region[Region XI]    0.005  0.010  -0.010    0.026
# Parent_LogIncome|Region[Region XII]   0.006  0.011  -0.011    0.028
# Parent_LogIncome|Region[Region XIII] -0.003  0.009  -0.023    0.012
#
#                                       mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# Parent_LogIncome                          0.000    0.000    5313.0    4749.0
# Children_Per_Household                    0.000    0.000   11170.0    6125.0
# C(Year)[2017]                             0.000    0.000    3580.0    5215.0
# C(Year)[2018]                             0.000    0.000    3588.0    4863.0
# C(Year)[2019]                             0.000    0.000    3939.0    5095.0
# C(Year)[2020]                             0.000    0.000    3567.0    5003.0
# C(Year)[2021]                             0.000    0.000    2921.0    4624.0
# C(Year)[2022]                             0.000    0.000    2865.0    4835.0
# C(Year)[2023]                             0.000    0.000    2959.0    4748.0
# Central_Child_Age                         0.000    0.000    9607.0    6654.0
# Central_Child_Age2                        0.000    0.000    9663.0    6199.0
# Child_Age_CLogIncome                      0.000    0.000    9383.0    6549.0
# Child_Age2_CLogIncome                     0.000    0.000    8469.0    6850.0
# Central_Parent_Age                        0.000    0.000    7285.0    6236.0
# Central_Parent_Age2                       0.000    0.000    7316.0    6114.0
# 1|Region_sigma                            0.001    0.001    1191.0    2343.0
# Parent_LogIncome|Region_sigma             0.000    0.000     753.0    1616.0
# 1|Region[ARMM]                            0.001    0.002    3693.0    2480.0
# 1|Region[CAR]                             0.001    0.002    2949.0    2388.0
# 1|Region[MIMAROPA]                        0.001    0.001    2907.0    3261.0
# 1|Region[NCR]                             0.001    0.001    3351.0    3431.0
# 1|Region[Region I]                        0.001    0.001    5100.0    4012.0
# 1|Region[Region II]                       0.001    0.001    4274.0    2979.0
# 1|Region[Region III]                      0.002    0.002    1848.0    2746.0
# 1|Region[Region IV-A]                     0.001    0.001    3403.0    3657.0
# 1|Region[Region IX]                       0.001    0.001    4691.0    3693.0
# 1|Region[Region V]                        0.001    0.001    5441.0    4009.0
# 1|Region[Region VI]                       0.001    0.001    4008.0    3753.0
# 1|Region[Region VII]                      0.001    0.001    2556.0    2742.0
# 1|Region[Region VIII]                     0.001    0.002    3242.0    2864.0
# 1|Region[Region X]                        0.002    0.002    1619.0    2481.0
# 1|Region[Region XI]                       0.002    0.002    1986.0    2747.0
# 1|Region[Region XII]                      0.002    0.002    1873.0    1830.0
# 1|Region[Region XIII]                     0.001    0.001    3366.0    3666.0
# Parent_LogIncome|Region[ARMM]             0.000    0.000    3920.0    2703.0
# Parent_LogIncome|Region[CAR]              0.000    0.000    3079.0    1891.0
# Parent_LogIncome|Region[MIMAROPA]         0.000    0.000    2335.0    2546.0
# Parent_LogIncome|Region[NCR]              0.000    0.000    2983.0    3059.0
# Parent_LogIncome|Region[Region I]         0.000    0.000    5604.0    3338.0
# Parent_LogIncome|Region[Region II]        0.000    0.000    6254.0    3368.0
# Parent_LogIncome|Region[Region III]       0.000    0.000    1502.0    2053.0
# Parent_LogIncome|Region[Region IV-A]      0.000    0.000    4218.0    4393.0
# Parent_LogIncome|Region[Region IX]        0.000    0.000    7006.0    3960.0
# Parent_LogIncome|Region[Region V]         0.000    0.000    7089.0    3885.0
# Parent_LogIncome|Region[Region VI]        0.000    0.000    4112.0    3104.0
# Parent_LogIncome|Region[Region VII]       0.000    0.000    2505.0    2608.0
# Parent_LogIncome|Region[Region VIII]      0.000    0.000    3754.0    3274.0
# Parent_LogIncome|Region[Region X]         0.000    0.000    1695.0    2711.0
# Parent_LogIncome|Region[Region XI]        0.000    0.000    2016.0    2755.0
# Parent_LogIncome|Region[Region XII]       0.000    0.000    2071.0    2459.0
# Parent_LogIncome|Region[Region XIII]      0.000    0.000    3447.0    2797.0
#
#                                       r_hat
# Parent_LogIncome                        1.0
# Children_Per_Household                  1.0
# C(Year)[2017]                           1.0
# C(Year)[2018]                           1.0
# C(Year)[2019]                           1.0
# C(Year)[2020]                           1.0
# C(Year)[2021]                           1.0
# C(Year)[2022]                           1.0
# C(Year)[2023]                           1.0
# Central_Child_Age                       1.0
# Central_Child_Age2                      1.0
# Child_Age_CLogIncome                    1.0
# Child_Age2_CLogIncome                   1.0
# Central_Parent_Age                      1.0
# Central_Parent_Age2                     1.0
# 1|Region_sigma                          1.0
# Parent_LogIncome|Region_sigma           1.0
# 1|Region[ARMM]                          1.0
# 1|Region[CAR]                           1.0
# 1|Region[MIMAROPA]                      1.0
# 1|Region[NCR]                           1.0
# 1|Region[Region I]                      1.0
# 1|Region[Region II]                     1.0
# 1|Region[Region III]                    1.0
# 1|Region[Region IV-A]                   1.0
# 1|Region[Region IX]                     1.0
# 1|Region[Region V]                      1.0
# 1|Region[Region VI]                     1.0
# 1|Region[Region VII]                    1.0
# 1|Region[Region VIII]                   1.0
# 1|Region[Region X]                      1.0
# 1|Region[Region XI]                     1.0
# 1|Region[Region XII]                    1.0
# 1|Region[Region XIII]                   1.0
# Parent_LogIncome|Region[ARMM]           1.0
# Parent_LogIncome|Region[CAR]            1.0
# Parent_LogIncome|Region[MIMAROPA]       1.0
# Parent_LogIncome|Region[NCR]            1.0
# Parent_LogIncome|Region[Region I]       1.0
# Parent_LogIncome|Region[Region II]      1.0
# Parent_LogIncome|Region[Region III]     1.0
# Parent_LogIncome|Region[Region IV-A]    1.0
# Parent_LogIncome|Region[Region IX]      1.0
# Parent_LogIncome|Region[Region V]       1.0
# Parent_LogIncome|Region[Region VI]      1.0
# Parent_LogIncome|Region[Region VII]     1.0
# Parent_LogIncome|Region[Region VIII]    1.0
# Parent_LogIncome|Region[Region X]       1.0
# Parent_LogIncome|Region[Region XI]      1.0
# Parent_LogIncome|Region[Region XII]     1.0
# Parent_LogIncome|Region[Region XIII]    1.0

# %% [markdown]
# <span style="font-family:monospace; font-size:18px;"><b>Hierarchical Modelling - Rural Only</b></span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import bambi as bmb
import arviz as az

# Use your complete_df as the dataset
df_rural = complete_df.copy()

# Filter for mother-son pairs (Parent_Sex == 'Mother', Child_Sex == 'Son')
df_rural = df_rural[(df_rural['Parent_Sex'] == 'Mother') & (df_rural['Child_Sex'] == 'Son')]

# ✅ Filter for rural households only (Urban_Rural == 2)
df_rural = df_rural[df_rural['Urban_Rural'] == 2]

# Ensure Region is categorical
df_rural['Region'] = df_rural['Region'].astype('category')

# --- Sample size and counts after cleaning ---
print(f"Sample size after all cleaning and filtering: {df_rural.shape[0]}")
print("\nCounts by Region:")
print(df_rural['Region'].value_counts())
print("\nCounts by Year:")
print(df_rural['Year'].value_counts())

# --- Descriptive statistics for key variables ---
print("\nDescriptive stats for key variables:")
print(df_rural[['Child_LogIncome', 'Parent_LogIncome', 'Children_Per_Household', 'Child_Age']].describe())

# --- Missing data summary ---
print("\nMissing values by column:")
print(df_rural.isnull().sum())

# --- Distribution plot for Child_LogIncome ---
df_rural['Child_LogIncome'].hist()
plt.title('Distribution of Child_LogIncome')
plt.xlabel('Child_LogIncome')
plt.ylabel('Frequency')
plt.show()

# --- Counts by Parent_Education, if available ---
if 'Parent_Education' in df_rural.columns:
    print("\nCounts by Parent_Education:")
    print(df_rural['Parent_Education'].value_counts())

# --- Session information for reproducibility ---
print("\nSession Info:")
print(f"Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"Bambi: {bmb.__version__}")
print(f"ArviZ: {az.__version__}")

# Specify the prior for Parent_LogIncome
priors = {
    "Parent_LogIncome": bmb.Prior("Normal", mu=0.4, sigma=0.10)
}

# Define the model formula
formula = (
    "Child_LogIncome ~ Parent_LogIncome + Children_Per_Household + C(Year) "
    "+ Central_Child_Age + Central_Child_Age2 "
    "+ Child_Age_CLogIncome + Child_Age2_CLogIncome "
    "+ Central_Parent_Age + Central_Parent_Age2 "
    "+ (1 + Parent_LogIncome | Region)"
)

# Fit the model
model = bmb.Model(formula, df_rural, family="gaussian", priors=priors)

result_rural = model.fit(
    draws=2000, tune=2000, random_seed=42, cores=1, chains=4, target_accept=0.995
)

# Show summary of selected parameters
print(az.summary(
    result_rural,
    var_names=[
        "~sigma", "~Intercept", "Parent_LogIncome", "Children_Per_Household", "C(Year)",
        "Central_Child_Age", "Central_Child_Age2", "Child_Age_CLogIncome", "Child_Age2_CLogIncome",
        "Central_Parent_Age", "Central_Parent_Age2"
    ]
))
# Out:
# Sample size after all cleaning and filtering: 9023
#
# Counts by Region:
# Region
# Region II      1048
# Region I        987
# CAR             967
# Region VI       817
# Region VIII     761
# Region III      733
# Region V        584
# Region X        516
# Region XIII     443
# MIMAROPA        437
# Region VII      416
# Region IV-A     383
# Region XI       305
# Region XII      275
# Region IX       226
# ARMM            125
# NCR               0
# Name: count, dtype: int64
#
# Counts by Year:
# Year
# 2021    1820
# 2022    1733
# 2023    1569
# 2018     992
# 2017     951
# 2020     733
# 2016     690
# 2019     535
# Name: count, dtype: int64
#
# Descriptive stats for key variables:
#        Child_LogIncome  Parent_LogIncome  Children_Per_Household    Child_Age
# count      9023.000000       9023.000000             9023.000000  9023.000000
# mean          5.915348          5.763408                2.989361    29.160368
# std           0.578614          0.795727                1.630015     3.867613
# min           2.484907          1.791759                1.000000    25.000000
# 25%           5.560682          5.298317                2.000000    26.000000
# 50%           5.857933          5.703782                3.000000    28.000000
# 75%           6.214608          6.118097                4.000000    31.000000
# max           8.507951          8.928640               12.000000    45.000000
#
# Missing values by column:
# OrigHHNUM                        0
# Year                             0
# Quarter                          0
# Household_Number                 0
# Region                           0
# Urban_Rural                      0
# Children_Per_Household           0
# Parent_Sex                       0
# Child_Sex                        0
# Parent_Age                       0
# Child_Age                        0
# Parent_Marital_Status            0
# Child_Marital_Status             0
# Parent_Educational_Attainment    0
# Child_Educational_Attainment     0
# Parent_Schooling_Years           0
# Child_Schooling_Years            0
# Parent_Primary_Occupation        0
# Child_Primary_Occupation         0
# Parent_WagePerDay                0
# Child_WagePerDay                 0
# Child_Birth_Cohort               0
# Parent_LogIncome                 0
# Child_LogIncome                  0
# Birth_Cohort                     0
# Central_Child_Age                0
# Central_Child_Age2               0
# Central_Parent_LogIncome         0
# Child_Age_CLogIncome             0
# Child_Age2_CLogIncome            0
# Central_Parent_Age               0
# Central_Parent_Age2              0
# dtype: int64
# Session Info:
# Python: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# Pandas: 2.3.0
# Bambi: 0.15.0
# ArviZ: 0.21.0
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, Parent_LogIncome, Children_Per_Household, C(Year), Central_Child_Age, Central_Child_Age2, Child_Age_CLogIncome, Child_Age2_CLogIncome, Central_Parent_Age, Central_Parent_Age2, 1|Region_sigma, 1|Region_offset, Parent_LogIncome|Region_sigma, Parent_LogIncome|Region_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 1697 seconds.
#                                        mean     sd  hdi_3%  hdi_97%  \
# Parent_LogIncome                      0.360  0.009   0.343    0.378
# Children_Per_Household               -0.010  0.003  -0.016   -0.003
# C(Year)[2017]                         0.099  0.024   0.054    0.143
# C(Year)[2018]                         0.137  0.024   0.094    0.184
# C(Year)[2019]                         0.202  0.027   0.150    0.252
# C(Year)[2020]                         0.252  0.025   0.203    0.298
# C(Year)[2021]                         0.267  0.021   0.228    0.309
# C(Year)[2022]                         0.272  0.022   0.231    0.312
# C(Year)[2023]                         0.322  0.022   0.281    0.365
# Central_Child_Age                     0.003  0.002  -0.000    0.006
# Central_Child_Age2                   -0.001  0.000  -0.001   -0.000
# Child_Age_CLogIncome                  0.003  0.002  -0.001    0.006
# Child_Age2_CLogIncome                -0.001  0.000  -0.001   -0.000
# Central_Parent_Age                    0.007  0.002   0.003    0.012
# Central_Parent_Age2                  -0.001  0.000  -0.001   -0.000
# 1|Region_sigma                        0.096  0.040   0.040    0.175
# Parent_LogIncome|Region_sigma         0.010  0.007   0.000    0.022
# 1|Region[ARMM]                       -0.097  0.067  -0.225    0.023
# 1|Region[CAR]                        -0.005  0.075  -0.144    0.116
# 1|Region[MIMAROPA]                    0.030  0.073  -0.088    0.165
# 1|Region[Region I]                    0.087  0.064  -0.016    0.214
# 1|Region[Region II]                   0.020  0.058  -0.105    0.113
# 1|Region[Region III]                  0.099  0.058  -0.019    0.198
# 1|Region[Region IV-A]                 0.129  0.063   0.006    0.240
# 1|Region[Region IX]                  -0.072  0.061  -0.184    0.042
# 1|Region[Region V]                    0.068  0.066  -0.037    0.197
# 1|Region[Region VI]                   0.006  0.061  -0.098    0.123
# 1|Region[Region VII]                  0.010  0.055  -0.097    0.112
# 1|Region[Region VIII]                -0.056  0.058  -0.171    0.042
# 1|Region[Region X]                   -0.070  0.060  -0.181    0.041
# 1|Region[Region XI]                  -0.023  0.059  -0.130    0.090
# 1|Region[Region XII]                 -0.118  0.072  -0.260   -0.001
# 1|Region[Region XIII]                 0.004  0.056  -0.109    0.105
# Parent_LogIncome|Region[ARMM]        -0.002  0.010  -0.022    0.015
# Parent_LogIncome|Region[CAR]          0.011  0.012  -0.005    0.035
# Parent_LogIncome|Region[MIMAROPA]    -0.007  0.012  -0.030    0.010
# Parent_LogIncome|Region[Region I]    -0.005  0.010  -0.026    0.011
# Parent_LogIncome|Region[Region II]    0.006  0.009  -0.008    0.025
# Parent_LogIncome|Region[Region III]   0.004  0.009  -0.012    0.023
# Parent_LogIncome|Region[Region IV-A]  0.003  0.010  -0.013    0.023
# Parent_LogIncome|Region[Region IX]   -0.000  0.009  -0.019    0.016
# Parent_LogIncome|Region[Region V]    -0.005  0.010  -0.026    0.012
# Parent_LogIncome|Region[Region VI]   -0.007  0.010  -0.027    0.009
# Parent_LogIncome|Region[Region VII]  -0.001  0.009  -0.019    0.016
# Parent_LogIncome|Region[Region VIII]  0.003  0.009  -0.013    0.022
# Parent_LogIncome|Region[Region X]     0.001  0.010  -0.018    0.018
# Parent_LogIncome|Region[Region XI]   -0.002  0.009  -0.021    0.015
# Parent_LogIncome|Region[Region XII]   0.002  0.012  -0.021    0.023
# Parent_LogIncome|Region[Region XIII] -0.001  0.009  -0.018    0.017
#
#                                       mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# Parent_LogIncome                          0.000    0.000    7891.0    5588.0
# Children_Per_Household                    0.000    0.000   16828.0    4958.0
# C(Year)[2017]                             0.000    0.000    4523.0    5418.0
# C(Year)[2018]                             0.000    0.000    4398.0    5346.0
# C(Year)[2019]                             0.000    0.000    5642.0    6157.0
# C(Year)[2020]                             0.000    0.000    4911.0    6077.0
# C(Year)[2021]                             0.000    0.000    4076.0    5543.0
# C(Year)[2022]                             0.000    0.000    4050.0    5490.0
# C(Year)[2023]                             0.000    0.000    4329.0    5311.0
# Central_Child_Age                         0.000    0.000   13539.0    6041.0
# Central_Child_Age2                        0.000    0.000   12279.0    5719.0
# Child_Age_CLogIncome                      0.000    0.000   11892.0    6756.0
# Child_Age2_CLogIncome                     0.000    0.000    9842.0    6379.0
# Central_Parent_Age                        0.000    0.000    9899.0    6443.0
# Central_Parent_Age2                       0.000    0.000   10308.0    6636.0
# 1|Region_sigma                            0.001    0.002    1243.0    1331.0
# Parent_LogIncome|Region_sigma             0.000    0.000     893.0    1375.0
# 1|Region[ARMM]                            0.001    0.001    4845.0    3274.0
# 1|Region[CAR]                             0.002    0.002    1802.0    2207.0
# 1|Region[MIMAROPA]                        0.002    0.003    2326.0    1954.0
# 1|Region[Region I]                        0.001    0.002    2581.0    2342.0
# 1|Region[Region II]                       0.001    0.001    3588.0    2843.0
# 1|Region[Region III]                      0.001    0.001    5808.0    4067.0
# 1|Region[Region IV-A]                     0.001    0.001    5297.0    3819.0
# 1|Region[Region IX]                       0.001    0.001    4793.0    3531.0
# 1|Region[Region V]                        0.001    0.002    2697.0    2143.0
# 1|Region[Region VI]                       0.001    0.001    2670.0    3206.0
# 1|Region[Region VII]                      0.001    0.001    6552.0    3963.0
# 1|Region[Region VIII]                     0.001    0.001    3700.0    2809.0
# 1|Region[Region X]                        0.001    0.002    4719.0    2901.0
# 1|Region[Region XI]                       0.001    0.001    8181.0    4626.0
# 1|Region[Region XII]                      0.002    0.003    2822.0    1919.0
# 1|Region[Region XIII]                     0.001    0.001    6572.0    3639.0
# Parent_LogIncome|Region[ARMM]             0.000    0.000    6063.0    3162.0
# Parent_LogIncome|Region[CAR]              0.000    0.000    1646.0    2626.0
# Parent_LogIncome|Region[MIMAROPA]         0.000    0.000    2165.0    1812.0
# Parent_LogIncome|Region[Region I]         0.000    0.000    2400.0    2431.0
# Parent_LogIncome|Region[Region II]        0.000    0.000    3447.0    3273.0
# Parent_LogIncome|Region[Region III]       0.000    0.000    5868.0    3452.0
# Parent_LogIncome|Region[Region IV-A]      0.000    0.000    5371.0    3132.0
# Parent_LogIncome|Region[Region IX]        0.000    0.000    6026.0    3098.0
# Parent_LogIncome|Region[Region V]         0.000    0.000    2493.0    2093.0
# Parent_LogIncome|Region[Region VI]        0.000    0.000    2383.0    2870.0
# Parent_LogIncome|Region[Region VII]       0.000    0.000    7716.0    3834.0
# Parent_LogIncome|Region[Region VIII]      0.000    0.000    4105.0    3069.0
# Parent_LogIncome|Region[Region X]         0.000    0.000    5708.0    3177.0
# Parent_LogIncome|Region[Region XI]        0.000    0.000    9751.0    4061.0
# Parent_LogIncome|Region[Region XII]       0.000    0.000    3114.0    1986.0
# Parent_LogIncome|Region[Region XIII]      0.000    0.000    9126.0    3880.0
#
#                                       r_hat
# Parent_LogIncome                        1.0
# Children_Per_Household                  1.0
# C(Year)[2017]                           1.0
# C(Year)[2018]                           1.0
# C(Year)[2019]                           1.0
# C(Year)[2020]                           1.0
# C(Year)[2021]                           1.0
# C(Year)[2022]                           1.0
# C(Year)[2023]                           1.0
# Central_Child_Age                       1.0
# Central_Child_Age2                      1.0
# Child_Age_CLogIncome                    1.0
# Child_Age2_CLogIncome                   1.0
# Central_Parent_Age                      1.0
# Central_Parent_Age2                     1.0
# 1|Region_sigma                          1.0
# Parent_LogIncome|Region_sigma           1.0
# 1|Region[ARMM]                          1.0
# 1|Region[CAR]                           1.0
# 1|Region[MIMAROPA]                      1.0
# 1|Region[Region I]                      1.0
# 1|Region[Region II]                     1.0
# 1|Region[Region III]                    1.0
# 1|Region[Region IV-A]                   1.0
# 1|Region[Region IX]                     1.0
# 1|Region[Region V]                      1.0
# 1|Region[Region VI]                     1.0
# 1|Region[Region VII]                    1.0
# 1|Region[Region VIII]                   1.0
# 1|Region[Region X]                      1.0
# 1|Region[Region XI]                     1.0
# 1|Region[Region XII]                    1.0
# 1|Region[Region XIII]                   1.0
# Parent_LogIncome|Region[ARMM]           1.0
# Parent_LogIncome|Region[CAR]            1.0
# Parent_LogIncome|Region[MIMAROPA]       1.0
# Parent_LogIncome|Region[Region I]       1.0
# Parent_LogIncome|Region[Region II]      1.0
# Parent_LogIncome|Region[Region III]     1.0
# Parent_LogIncome|Region[Region IV-A]    1.0
# Parent_LogIncome|Region[Region IX]      1.0
# Parent_LogIncome|Region[Region V]       1.0
# Parent_LogIncome|Region[Region VI]      1.0
# Parent_LogIncome|Region[Region VII]     1.0
# Parent_LogIncome|Region[Region VIII]    1.0
# Parent_LogIncome|Region[Region X]       1.0
# Parent_LogIncome|Region[Region XI]      1.0
# Parent_LogIncome|Region[Region XII]     1.0
# Parent_LogIncome|Region[Region XIII]    1.0
